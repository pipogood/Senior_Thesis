# %% [markdown]
# # CNN model

# %%
from pylsl import StreamInlet, resolve_stream
import numpy as np
from scipy.fft import fft2, fftshift
import matplotlib.pyplot as plt
from scipy.signal import butter, lfilter
from scipy.signal import welch
import mne
import pywt
import pickle
import keras
from keras.models import load_model
from sklearn.metrics import confusion_matrix
import seaborn as sns
from matplotlib.animation import FuncAnimation
from datetime import datetime


pretrained_model = load_model("CNN_model1s_3c_weights.h5")

epoch_2s = np.zeros(shape=(7,251))

# first resolve an EEG stream on the lab network
print("looking for an EEG stream...")
streams = resolve_stream()
print(streams)

data = []
time_count = 0.0
time_all = 0.0
time_interval = 0.1

# create a new inlet to read from the stream
inlet = StreamInlet(streams[0])

fs = 250.0
 
channels = ["Fz","C3", "Cz", "C4","Pz","PO7","PO8"]

info = mne.create_info(
    ch_names= channels,
    ch_types= ['eeg']*len(channels),
    sfreq= fs
)

def call_pywt(new_data):
    component_num = 7
    train_cwt = np.ndarray(shape=(new_data.shape[0], new_data.shape[2], component_num))
    for jj in range(0, new_data.shape[0]):
        train_cwt[jj] = new_data[jj].T

    scales = range(1,31)
    waveletname = 'morl'
    train_size = new_data.shape[0]
    train_data_cwt = np.ndarray(shape=(train_size, len(scales), new_data.shape[2], component_num))

    for ii in range(0,train_size):
        for jj in range(0,component_num):
            signal = train_cwt[ii, :, jj]
            coeff, _ = pywt.cwt(signal, scales, waveletname, 1)
            coeff_ = coeff[:,:new_data.shape[2]]  
            train_data_cwt[ii, :, :, jj] = coeff_

    train_cwt_stack = np.ndarray(shape=(train_size, len(scales)*component_num, new_data.shape[2]))

    for jj in range(0,train_data_cwt.shape[0]):
        train_cwt_stack[jj] = np.vstack((train_data_cwt[jj,:,:,0], train_data_cwt[jj,:,:,1], train_data_cwt[jj,:,:,2], train_data_cwt[jj,:,:,3], train_data_cwt[jj,:,:,4], train_data_cwt[jj,:,:,5], train_data_cwt[jj,:,:,6]))
    return train_cwt_stack


while True:
    sample, timestamp = inlet.pull_sample()

    if timestamp:
        data1 = sample[0:6]
        data1.append(sample[7])
        data.append(data1)  

        time_count += 1 * 0.004
        time_count = np.round(time_count ,3)
        time_all += 1 * 0.004

        if time_count == time_interval:

            data = np.asarray(data)
            epoch_2s = np.delete(epoch_2s, slice(0,int(time_interval/0.004)), axis =1)
            epoch_2s = np.append(epoch_2s, data.T, axis= 1)

            # print(epoch_2s)

            # data = np.asarray(data)
            # data = np.transpose(data)
            # epoch_2s = data
            # print(epoch_2s)
            
            # raw = mne.io.RawArray(epoch_2s, info, verbose=False)
            # eeg1 = raw.copy().filter(l_freq=8.0, h_freq=30.0, method = 'iir', iir_params= {"order": 5, "ftype":'butter'}, verbose = False)
            # eeg1 = eeg1.copy().set_eeg_reference(ref_channels="average", verbose=False)

            raw = mne.EpochsArray(epoch_2s.reshape(1,7,251), info, verbose=False)
            eeg1 = raw.copy().filter(l_freq=6.0, h_freq=32.0, method = 'iir', iir_params= {"order": 5, "ftype":'butter'}, verbose = False)
            eeg1 = eeg1.copy().set_eeg_reference(ref_channels="average", verbose=False)

            # print(np.shape(eeg1.get_data()))
            # print("*****************Fitered*******************")
            # print(eeg1.get_data())
            # print(eeg1.get_data().max())

            with open('trained_csp_model.pkl', 'rb') as file:
                trained_csp = pickle.load(file)

            new_data = trained_csp.transform(eeg1.get_data().reshape(1,7,251))

            # print("*****************CSP*******************")
            # print(new_data)

            train_cwt_stack = call_pywt(new_data)

            # print("*****************CWT*******************")
            # print(train_cwt_stack)


            y_pred_raw = pretrained_model.predict(train_cwt_stack ,verbose=False)

            # Append the predicted class to the real-time plot data
            # x_vals.append(time_all)
            # y_vals.append(np.argmax(y_pred_raw))

            print("************************************")
            print(y_pred_raw)
            print("predict class", np.argmax(y_pred_raw))
        
            data = np.ndarray.tolist(data)
            data = []
            time_count = 0.0
        
        # if time_all >= 10.0:
        #     break
# Out:
# looking for an EEG stream...
# [<pylsl.pylsl.StreamInfo object at 0x0000016168A442D0>, <pylsl.pylsl.StreamInfo object at 0x00000161D7096B90>]
# ************************************
# [[0. 0. 1.]]
# predict class 2
# ************************************
# [[0. 0. 1.]]
# predict class 2
# ************************************
# [[0. 0. 1.]]
# predict class 2
# ************************************
# [[0. 0. 1.]]
# predict class 2
# ************************************
# [[1.000000e+00 0.000000e+00 9.910584e-35]]
# predict class 0
# ************************************
# [[0. 1. 0.]]
# predict class 1
# ************************************
# [[1. 0. 0.]]
# predict class 0
# ************************************
# [[1. 0. 0.]]
# predict class 0
# ************************************
# [[0. 1. 0.]]
# predict class 1
# ************************************
# [[0. 1. 0.]]
# predict class 1
# ************************************
# [[0.129513   0.30088893 0.5695981 ]]
# predict class 2
# ************************************
# [[0.03392842 0.7148223  0.25124928]]
# predict class 1
# ************************************
# [[0.3424095  0.429041   0.22854955]]
# predict class 1
# ************************************
# [[0.29924366 0.04554206 0.65521425]]
# predict class 2
# ************************************
# [[0.28523117 0.04244885 0.67231995]]
# predict class 2
# ************************************
# [[0.10742194 0.04114156 0.8514365 ]]
# predict class 2
# ************************************
# [[0.14691967 0.4420119  0.41106844]]
# predict class 1
# ************************************
# [[0.17724031 0.3203434  0.50241625]]
# predict class 2
# ************************************
# [[0.44439486 0.026344   0.52926123]]
# predict class 2
# ************************************
# [[0.62728655 0.09389472 0.2788188 ]]
# predict class 0
# ************************************
# [[0.5852883  0.20126845 0.21344328]]
# predict class 0
# ************************************
# [[0.664464   0.03555048 0.29998553]]
# predict class 0
# ************************************
# [[0.50156724 0.00451596 0.4939168 ]]
# predict class 0
# ************************************
# [[0.39997193 0.29327497 0.30675313]]
# predict class 0
# ************************************
# [[0.10900097 0.6771266  0.21387246]]
# predict class 1
# ************************************
# [[0.10245171 0.15191469 0.7456336 ]]
# predict class 2
# ************************************
# [[0.05680793 0.25830087 0.68489116]]
# predict class 2
# ************************************
# [[0.00814668 0.70401126 0.28784215]]
# predict class 1
# ************************************
# [[0.08510417 0.1444874  0.7704084 ]]
# predict class 2
# ************************************
# [[0.17037877 0.17272893 0.6568923 ]]
# predict class 2
# ************************************
# [[0.43236366 0.39333767 0.17429864]]
# predict class 0
# ************************************
# [[0.77215254 0.06195674 0.16589068]]
# predict class 0
# ************************************
# [[0.1029968  0.09196137 0.8050418 ]]
# predict class 2
# ************************************
# [[0.02619478 0.10665364 0.8671516 ]]
# predict class 2
# ************************************
# [[0.338156   0.20296127 0.45888275]]
# predict class 2
# ************************************
# [[0.31816527 0.1623407  0.51949406]]
# predict class 2
# ************************************
# [[0.11733796 0.0644886  0.81817347]]
# predict class 2
# ************************************
# [[0.10094661 0.31094316 0.5881102 ]]
# predict class 2
# ************************************
# [[0.06256817 0.7838531  0.15357865]]
# predict class 1
# ************************************
# [[0.33920807 0.30086207 0.35992986]]
# predict class 2
# ************************************
# [[0.46692815 0.03638765 0.49668428]]
# predict class 2
# ************************************
# [[0.38189578 0.01358617 0.60451806]]
# predict class 2
# ************************************
# [[0.09380545 0.10102554 0.805169  ]]
# predict class 2
# ************************************
# [[0.01602867 0.0253115  0.9586598 ]]
# predict class 2
# ************************************
# [[0.13046633 0.29405418 0.5754795 ]]
# predict class 2
# ************************************
# [[0.11644898 0.56206715 0.32148397]]
# predict class 1
# ************************************
# [[0.19186392 0.02320779 0.7849282 ]]
# predict class 2
# ************************************
# [[0.2786853  0.00688359 0.71443105]]
# predict class 2
# ************************************
# [[0.12425353 0.06790602 0.80784047]]
# predict class 2
# ************************************
# [[0.17205459 0.39477056 0.43317482]]
# predict class 2
# ************************************
# [[0.31130028 0.38975915 0.29894054]]
# predict class 1
# ************************************
# [[0.34908476 0.561457   0.08945826]]
# predict class 1
# ************************************
# [[0.6461312  0.0290462  0.32482255]]
# predict class 0
# ************************************
# [[0.32341084 0.00495297 0.67163616]]
# predict class 2
# ************************************
# [[0.6908104  0.20840901 0.10078056]]
# predict class 0
# ************************************
# [[0.48901948 0.4845682  0.02641232]]
# predict class 0
# ************************************
# [[0.08617027 0.612343   0.3014867 ]]
# predict class 1
# ************************************
# [[0.06507669 0.8772506  0.05767279]]
# predict class 1
# ************************************
# [[0.00682818 0.8062311  0.18694079]]
# predict class 1
# ************************************
# [[0.02923795 0.14129943 0.82946265]]
# predict class 2
# ************************************
# [[0.16689649 0.04139608 0.7917075 ]]
# predict class 2
# ************************************
# [[0.11948641 0.06791968 0.81259394]]
# predict class 2
# ************************************
# [[0.14930868 0.11488619 0.7358051 ]]
# predict class 2
# ************************************
# [[0.23364815 0.11634485 0.65000707]]
# predict class 2
# ************************************
# [[0.0781701  0.04086347 0.8809664 ]]
# predict class 2
# ************************************
# [[0.03203105 0.00328945 0.96467954]]
# predict class 2
# ************************************
# [[4.0245216e-02 8.2270446e-04 9.5893204e-01]]
# predict class 2
# ************************************
# [[0.01909211 0.01121425 0.9696936 ]]
# predict class 2
# ************************************
# [[0.00302354 0.00399914 0.9929773 ]]
# predict class 2
# ************************************
# [[0.15855867 0.09121731 0.750224  ]]
# predict class 2
# ************************************
# [[0.55580246 0.30168656 0.14251101]]
# predict class 0
# ************************************
# [[0.24757794 0.11552833 0.63689375]]
# predict class 2
# ************************************
# [[0.31581596 0.03436934 0.64981467]]
# predict class 2
# ************************************
# [[0.37897784 0.31507286 0.30594933]]
# predict class 0
# ************************************
# [[0.1608942  0.24132659 0.5977792 ]]
# predict class 2
# ************************************
# [[0.20363714 0.30891103 0.48745176]]
# predict class 2
# ************************************
# [[0.17773889 0.6377604  0.18450071]]
# predict class 1
# ************************************
# [[0.11094975 0.2169736  0.67207664]]
# predict class 2
# ************************************
# [[0.17052433 0.06372195 0.7657537 ]]
# predict class 2
# ************************************
# [[0.05062296 0.10869645 0.8406806 ]]
# predict class 2
# ************************************
# [[0.16103747 0.08098956 0.75797296]]
# predict class 2
# ************************************
# [[0.2862051  0.10653445 0.6072604 ]]
# predict class 2
# ************************************
# [[0.30492502 0.06680487 0.62827015]]
# predict class 2
# ************************************
# [[0.09250288 0.0313092  0.8761879 ]]
# predict class 2
# ************************************
# [[0.04945068 0.01970463 0.9308447 ]]
# predict class 2
# ************************************
# [[0.01890461 0.01208701 0.96900845]]
# predict class 2
# ************************************
# [[0.02480751 0.10705079 0.8681418 ]]
# predict class 2
# ************************************
# [[0.20198658 0.35754648 0.44046703]]
# predict class 2
# ************************************
# [[0.13080123 0.2372031  0.63199574]]
# predict class 2
# ************************************
# [[0.45111763 0.25556746 0.2933149 ]]
# predict class 0
# ************************************
# [[0.95923525 0.01734779 0.02341699]]
# predict class 0
# ************************************
# [[0.479417  0.0103812 0.5102018]]
# predict class 2
# ************************************
# [[0.3228829  0.04244933 0.63466775]]
# predict class 2
# ************************************
# [[0.20232622 0.05190219 0.7457716 ]]
# predict class 2
# ************************************
# [[0.00619058 0.00236504 0.9914444 ]]
# predict class 2
# ************************************
# [[0.04148005 0.01723933 0.9412806 ]]
# predict class 2
# ************************************
# [[0.382124   0.11859955 0.49927637]]
# predict class 2
# ************************************
# [[0.54361635 0.07893226 0.37745142]]
# predict class 0
# ************************************
# [[0.56648004 0.01412145 0.4193985 ]]
# predict class 0
# ************************************
# [[0.21977982 0.00710204 0.7731181 ]]
# predict class 2
# ************************************
# [[0.19063266 0.03506732 0.7743    ]]
# predict class 2
# ************************************
# [[0.23883308 0.2364795  0.5246874 ]]
# predict class 2
# ************************************
# [[0.5146509  0.3230681  0.16228092]]
# predict class 0
# ************************************
# [[0.5902586  0.15955986 0.25018147]]
# predict class 0
# ************************************
# [[0.1352194  0.11982762 0.7449529 ]]
# predict class 2
# ************************************
# [[0.18917239 0.0799446  0.730883  ]]
# predict class 2
# ************************************
# [[0.30868474 0.0405047  0.65081066]]
# predict class 2
# ************************************
# [[0.0367422  0.03181493 0.93144286]]
# predict class 2
# ************************************
# [[0.15546209 0.55526185 0.2892761 ]]
# predict class 1
# ************************************
# [[0.02414138 0.9498145  0.02604408]]
# predict class 1
# ************************************
# [[0.0894082  0.11544114 0.79515064]]
# predict class 2
# ************************************
# [[0.14481741 0.03221722 0.8229654 ]]
# predict class 2
# ************************************
# [[0.08118422 0.45890316 0.45991266]]
# predict class 2
# ************************************
# [[0.0188887 0.1264897 0.8546216]]
# predict class 2
# ************************************
# [[0.0198665  0.02405482 0.9560787 ]]
# predict class 2
# ************************************
# [[0.37486494 0.12419311 0.500942  ]]
# predict class 2
# ************************************
# [[0.25455013 0.32742783 0.4180221 ]]
# predict class 2
# ************************************
# [[0.04693937 0.3795902  0.5734704 ]]
# predict class 2
# ************************************
# [[0.55500025 0.23334417 0.2116556 ]]
# predict class 0
# ************************************
# [[0.5801229  0.15305641 0.26682076]]
# predict class 0
# ************************************
# [[0.28611156 0.2109453  0.50294316]]
# predict class 2
# ************************************
# [[0.2506889  0.02193242 0.72737867]]
# predict class 2
# ************************************
# [[0.05124016 0.02722325 0.92153656]]
# predict class 2
# ************************************
# [[0.3980471  0.12423353 0.47771937]]
# predict class 2
# ************************************
# [[0.14210342 0.07067706 0.7872195 ]]
# predict class 2
# ************************************
# [[0.1926487  0.45265383 0.35469747]]
# predict class 1
# ************************************
# [[0.12087699 0.78802234 0.09110074]]
# predict class 1
# ************************************
# [[0.6432244  0.04311546 0.31366012]]
# predict class 0
# ************************************
# [[0.79085565 0.03691241 0.17223199]]
# predict class 0
# ************************************
# [[0.15883084 0.35782072 0.4833484 ]]
# predict class 2
# ************************************
# [[0.00482506 0.09182239 0.90335256]]
# predict class 2
# ************************************
# [[0.03285356 0.02981845 0.93732804]]
# predict class 2
# ************************************
# [[0.2772876  0.02105991 0.7016525 ]]
# predict class 2
# ************************************
# [[0.43353721 0.09458815 0.47187465]]
# predict class 2
# ************************************
# [[0.06085785 0.02914822 0.90999395]]
# predict class 2
# ************************************
# [[0.2327646  0.32488948 0.44234586]]
# predict class 2
# ************************************
# [[0.22456594 0.52468497 0.25074914]]
# predict class 1
# ************************************
# [[0.49752554 0.14013982 0.36233458]]
# predict class 0
# ************************************
# [[0.8533809  0.01137902 0.13524008]]
# predict class 0
# ************************************
# [[0.85294247 0.02727685 0.11978075]]
# predict class 0
# ************************************
# [[0.8789103  0.03928868 0.08180103]]
# predict class 0
# ************************************
# [[0.10096826 0.04617027 0.85286146]]
# predict class 2
# ************************************
# [[0.01355023 0.07815095 0.9082988 ]]
# predict class 2
# ************************************
# [[0.5725828  0.21477398 0.21264328]]
# predict class 0
# ************************************
# [[0.7472184  0.0625573  0.19022438]]
# predict class 0
# ************************************
# [[0.37077186 0.14790507 0.48132312]]
# predict class 2
# ************************************
# [[0.1597856  0.12905341 0.711161  ]]
# predict class 2
# ************************************
# [[0.5714745  0.02843219 0.4000933 ]]
# predict class 0
# ************************************
# [[0.68556046 0.01143668 0.30300286]]
# predict class 0
# ************************************
# [[0.09989744 0.00438754 0.89571494]]
# predict class 2
# ************************************
# [[0.27265567 0.07145569 0.6558886 ]]
# predict class 2
# ************************************
# [[0.08988229 0.37935564 0.5307621 ]]
# predict class 2
# ************************************
# [[0.04578871 0.2369247  0.7172866 ]]
# predict class 2
# ************************************
# [[0.14886257 0.17584288 0.6752946 ]]
# predict class 2
# ************************************
# [[0.06822194 0.07435322 0.8574248 ]]
# predict class 2
# ************************************
# [[0.31402498 0.13997717 0.54599786]]
# predict class 2
# ************************************
# [[0.4602439  0.03521529 0.50454086]]
# predict class 2
# ************************************
# [[0.70383567 0.02070511 0.27545923]]
# predict class 0
# ************************************
# [[0.42637655 0.0866702  0.48695323]]
# predict class 2
# ************************************
# [[0.14323361 0.4023548  0.4544116 ]]
# predict class 2
# ************************************
# [[0.0765007  0.33987865 0.5836207 ]]
# predict class 2
# ************************************
# [[0.02824298 0.04003839 0.9317187 ]]
# predict class 2
# ************************************
# [[0.02979971 0.06140702 0.9087933 ]]
# predict class 2
# ************************************
# [[0.1468649  0.05424986 0.7988852 ]]
# predict class 2
# ************************************
# [[0.50830454 0.17518838 0.316507  ]]
# predict class 0
# ************************************
# [[0.44182003 0.07500003 0.48317996]]
# predict class 2
# ************************************
# [[0.29236028 0.0095909  0.69804883]]
# predict class 2
# ************************************
# [[0.4664196  0.01499389 0.51858646]]
# predict class 2
# ************************************
# [[0.15357196 0.5343826  0.3120455 ]]
# predict class 1
# ************************************
# [[0.08738045 0.37645862 0.536161  ]]
# predict class 2
# ************************************
# [[0.49956766 0.06866322 0.43176913]]
# predict class 0
# ************************************
# [[0.2534376  0.20687707 0.53968537]]
# predict class 2
# ************************************
# [[0.19874114 0.51656705 0.2846918 ]]
# predict class 1
# ************************************
# [[0.29419363 0.37746832 0.32833812]]
# predict class 1
# ************************************
# [[0.21062309 0.02658753 0.76278937]]
# predict class 2
# ************************************
# [[0.45062724 0.02315397 0.52621883]]
# predict class 2
# ************************************
# [[0.24941489 0.05038118 0.7002039 ]]
# predict class 2
# ************************************
# [[0.01807599 0.02274179 0.95918226]]
# predict class 2
# ************************************
# [[0.12912545 0.13200341 0.73887116]]
# predict class 2
# ************************************
# [[0.40160215 0.29070455 0.3076933 ]]
# predict class 0
# ************************************
# [[0.10712291 0.36343104 0.52944607]]
# predict class 2
# ************************************
# [[0.2334358  0.08210226 0.68446195]]
# predict class 2
# ************************************
# [[0.73208886 0.01720611 0.25070506]]
# predict class 0
# ************************************
# [[0.5040498  0.04885022 0.4471    ]]
# predict class 0
# ************************************
# [[0.101653   0.14042574 0.75792134]]
# predict class 2
# ************************************
# [[0.39797407 0.22472991 0.37729603]]
# predict class 0
# ************************************
# [[0.7139876  0.07858734 0.20742509]]
# predict class 0
# ************************************
# [[0.1507378  0.03292869 0.81633353]]
# predict class 2
# ************************************
# [[0.28392988 0.50938374 0.20668639]]
# predict class 1
# ************************************
# [[0.15043549 0.8222609  0.02730362]]
# predict class 1
# ************************************
# [[0.13900839 0.35521007 0.5057816 ]]
# predict class 2
# ************************************
# [[0.18336251 0.41248643 0.40415105]]
# predict class 0
# ************************************
# [[0.86855084 0.05359801 0.0778512 ]]
# predict class 0
# ************************************
# [[0.3150978  0.20147887 0.48342332]]
# predict class 2
# ************************************
# [[0.05635722 0.43455967 0.50908315]]
# predict class 2
# ************************************
# [[0.17615488 0.0161406  0.80770457]]
# predict class 2
# ************************************
# [[0.3469961  0.03484036 0.6181635 ]]
# predict class 2
# ************************************
# [[0.13535923 0.4982596  0.36638123]]
# predict class 1
# ************************************
# [[0.07189302 0.04309341 0.8850135 ]]
# predict class 2
# ************************************
# [[0.08959784 0.01315785 0.89724433]]
# predict class 2
# ************************************
# [[0.04859117 0.7836012  0.16780764]]
# predict class 1
# ************************************
# [[0.040379 0.248313 0.711308]]
# predict class 2
# ************************************
# [[0.867638   0.00782123 0.12454078]]
# predict class 0
# ************************************
# [[0.24030969 0.05761013 0.7020802 ]]
# predict class 2
# ************************************
# [[0.05461254 0.1677928  0.7775947 ]]
# predict class 2
# ************************************
# [[0.05371431 0.42815474 0.51813096]]
# predict class 2
# ************************************
# [[0.03620158 0.37050682 0.5932916 ]]
# predict class 2
# ************************************
# [[0.03655088 0.52785385 0.43559536]]
# predict class 1
# ************************************
# [[0.05758981 0.48677492 0.4556353 ]]
# predict class 1
# ************************************
# [[0.03626134 0.0732144  0.8905243 ]]
# predict class 2
# ************************************
# [[0.22485073 0.04384318 0.73130614]]
# predict class 2
# ************************************
# [[0.06212218 0.03067133 0.9072065 ]]
# predict class 2
# ************************************
# [[0.05542305 0.03633857 0.9082384 ]]
# predict class 2
# ************************************
# [[0.4244389  0.06067855 0.51488256]]
# predict class 2
# ************************************
# [[0.36390814 0.01536952 0.62072235]]
# predict class 2
# ************************************
# [[0.04046391 0.00551446 0.95402163]]
# predict class 2
# ************************************
# [[0.03830107 0.10716734 0.8545315 ]]
# predict class 2
# ************************************
# [[0.12160327 0.43817568 0.44022098]]
# predict class 2
# ************************************
# [[0.59118116 0.03280335 0.37601537]]
# predict class 0
# ************************************
# [[0.5941449  0.05379748 0.3520576 ]]
# predict class 0
# ************************************
# [[0.13831694 0.10207123 0.7596118 ]]
# predict class 2
# ************************************
# [[0.6981367  0.01919132 0.282672  ]]
# predict class 0
# ************************************
# [[0.94510347 0.00404251 0.05085399]]
# predict class 0
# ************************************
# [[0.52000517 0.04358582 0.436409  ]]
# predict class 0
# ************************************
# [[0.04764    0.14559281 0.8067672 ]]
# predict class 2
# ************************************
# [[0.04766681 0.6242401  0.32809314]]
# predict class 1
# ************************************
# [[0.0449551  0.37613928 0.57890564]]
# predict class 2
# ************************************
# [[0.11705908 0.03057075 0.8523702 ]]
# predict class 2
# ************************************
# [[0.6848626  0.02817507 0.28696236]]
# predict class 0
# ************************************
# [[0.32464314 0.17798589 0.49737102]]
# predict class 2
# ************************************
# [[0.11204706 0.25607398 0.631879  ]]
# predict class 2
# ************************************
# [[0.03122674 0.39286196 0.57591134]]
# predict class 2
# ************************************
# [[0.08618934 0.36386245 0.5499482 ]]
# predict class 2
# ************************************
# [[0.71661246 0.01862067 0.26476693]]
# predict class 0
# ************************************
# [[0.8662589  0.00453977 0.12920128]]
# predict class 0
# ************************************
# [[0.5979743  0.07303962 0.32898617]]
# predict class 0
# ************************************
# [[0.30917028 0.48436272 0.20646693]]
# predict class 1
# ************************************
# [[0.12953593 0.09196833 0.7784958 ]]
# predict class 2
# ************************************
# [[0.28696293 0.01345392 0.6995832 ]]
# predict class 2
# ************************************
# [[0.6565726  0.01122183 0.33220562]]
# predict class 0
# ************************************
# [[0.20176493 0.00237207 0.79586303]]
# predict class 2
# ************************************
# [[0.19366671 0.04441963 0.7619137 ]]
# predict class 2
# ************************************
# [[0.27495027 0.20675604 0.51829374]]
# predict class 2
# ************************************
# [[0.32506576 0.15701905 0.5179151 ]]
# predict class 2
# ************************************
# [[0.38815644 0.22471683 0.38712674]]
# predict class 0
# ************************************
# [[0.29242626 0.12528865 0.5822851 ]]
# predict class 2
# ************************************
# [[0.01922573 0.00803591 0.9727384 ]]
# predict class 2
# ************************************
# [[0.03307722 0.03002493 0.93689775]]
# predict class 2
# ************************************
# [[0.15848061 0.3105653  0.53095406]]
# predict class 2
# ************************************
# [[0.1871376  0.03335524 0.77950716]]
# predict class 2
# ************************************
# [[0.25918597 0.03387601 0.706938  ]]
# predict class 2
# ************************************
# [[0.07409272 0.19515075 0.7307565 ]]
# predict class 2
# ************************************
# [[0.04860924 0.84085006 0.11054075]]
# predict class 1
# ************************************
# [[0.04028088 0.25472414 0.704995  ]]
# predict class 2
# ************************************
# [[0.33751374 0.06471681 0.59776944]]
# predict class 2
# ************************************
# [[0.61444813 0.02363831 0.3619136 ]]
# predict class 0
# ************************************
# [[0.3446491  0.00916272 0.64618814]]
# predict class 2
# ************************************
# [[0.10484128 0.02922238 0.8659364 ]]
# predict class 2
# ************************************
# [[0.06558001 0.02563543 0.90878457]]
# predict class 2
# ************************************
# [[0.24008402 0.1439958  0.6159202 ]]
# predict class 2
# ************************************
# [[0.289778   0.52343416 0.18678789]]
# predict class 1
# ************************************
# [[0.05651547 0.00703215 0.9364523 ]]
# predict class 2
# ************************************
# [[0.11558738 0.00862621 0.8757864 ]]
# predict class 2
# ************************************
# [[0.43481326 0.27532515 0.28986156]]
# predict class 0
# ************************************
# [[0.30841687 0.1744995  0.5170836 ]]
# predict class 2
# ************************************
# [[0.21346107 0.02436455 0.7621743 ]]
# predict class 2
# ************************************
# [[0.09274147 0.01589154 0.89136696]]
# predict class 2
# ************************************
# [[0.03425847 0.00276919 0.96297234]]
# predict class 2
# ************************************
# [[0.0245304  0.00405461 0.97141504]]
# predict class 2
# ************************************
# [[0.06645069 0.03496759 0.8985817 ]]
# predict class 2
# ************************************
# [[0.04777253 0.00255442 0.949673  ]]
# predict class 2
# ************************************
# [[0.02524853 0.00527267 0.9694788 ]]
# predict class 2
# ************************************
# [[0.20650178 0.13246502 0.6610332 ]]
# predict class 2
# ************************************
# [[0.32337803 0.08167468 0.5949472 ]]
# predict class 2
# ************************************
# [[0.16088422 0.10762516 0.73149055]]
# predict class 2
# ************************************
# [[0.152697   0.33755344 0.5097495 ]]
# predict class 2
# ************************************
# [[0.19731724 0.37395212 0.4287306 ]]
# predict class 2
# ************************************
# [[0.29529595 0.36455935 0.34014463]]
# predict class 1
# ************************************
# [[0.3580772  0.02157221 0.62035054]]
# predict class 2
# ************************************
# [[0.0514852  0.00398148 0.9445333 ]]
# predict class 2
# ************************************
# [[0.04545465 0.14779164 0.8067537 ]]
# predict class 2
# ************************************
# [[0.0779052  0.5860243  0.33607054]]
# predict class 1
# ************************************
# [[0.02702066 0.03398439 0.93899494]]
# predict class 2
# ************************************
# [[0.09136134 0.21747297 0.69116575]]
# predict class 2
# ************************************
# [[0.00649975 0.98062116 0.01287908]]
# predict class 1
# ************************************
# [[0.02037606 0.3785597  0.60106426]]
# predict class 2
# ************************************
# [[0.19633006 0.03211387 0.771556  ]]
# predict class 2
# ************************************
# [[0.7594768  0.03533381 0.20518933]]
# predict class 0
# ************************************
# [[0.40579838 0.0139629  0.5802387 ]]
# predict class 2
# ************************************
# [[0.66272366 0.03292521 0.30435115]]
# predict class 0
# ************************************
# [[0.29087874 0.27929613 0.42982522]]
# predict class 2
# ************************************
# [[0.03953499 0.07948311 0.88098186]]
# predict class 2
# ************************************
# [[0.15320978 0.2779382  0.568852  ]]
# predict class 2
# ************************************
# [[0.677777   0.05540363 0.2668194 ]]
# predict class 0
# ************************************
# [[0.09509041 0.01638673 0.8885228 ]]
# predict class 2
# ************************************
# [[0.4557961  0.35203794 0.19216594]]
# predict class 0
# ************************************
# [[0.20965672 0.66661865 0.12372471]]
# predict class 1
# ************************************
# [[0.02915121 0.46868828 0.5021605 ]]
# predict class 2
# ************************************
# [[0.00588196 0.00158709 0.992531  ]]
# predict class 2
# ************************************
# [[3.8116862e-04 9.2560000e-04 9.9869329e-01]]
# predict class 2
# ************************************
# [[0.0183859  0.00520708 0.97640705]]
# predict class 2
# ************************************
# [[1.7785288e-03 1.7414139e-04 9.9804735e-01]]
# predict class 2
# ************************************
# [[1.1907391e-05 8.0886248e-06 9.9997997e-01]]
# predict class 2
# ************************************
# [[4.7321386e-08 9.9068211e-07 9.9999893e-01]]
# predict class 2
# ************************************
# [[3.8148501e-04 1.8485395e-06 9.9961662e-01]]
# predict class 2
# ************************************
# [[2.6299996e-02 2.2335780e-06 9.7369778e-01]]
# predict class 2
# ************************************
# [[1.16624335e-07 4.23847490e-09 9.99999881e-01]]
# predict class 2
# ************************************
# [[9.3084829e-08 4.3820464e-08 9.9999988e-01]]
# predict class 2
# ************************************
# [[8.1151738e-05 6.0392867e-06 9.9991286e-01]]
# predict class 2
# ************************************
# [[0.00829913 0.00197852 0.98972243]]
# predict class 2
# ************************************
# [[3.1808797e-06 1.2860836e-05 9.9998391e-01]]
# predict class 2
# ************************************
# [[1.3587093e-06 2.7526141e-11 9.9999869e-01]]
# predict class 2
# ************************************
# [[5.1194552e-04 7.1751054e-09 9.9948800e-01]]
# predict class 2
# ************************************
# [[2.2991546e-07 9.2448687e-07 9.9999881e-01]]
# predict class 2
# ************************************
# [[1.2050954e-09 5.7621783e-04 9.9942386e-01]]
# predict class 2
# ************************************
# [[5.9162659e-07 4.6881404e-02 9.5311803e-01]]
# predict class 2
# ************************************
# [[0.06395328 0.00514811 0.93089867]]
# predict class 2
# ************************************
# [[1.8254770e-02 8.4428569e-07 9.8174435e-01]]
# predict class 2
# ************************************
# [[1.4689401e-05 1.3234261e-06 9.9998403e-01]]
# predict class 2
# ************************************
# [[1.0638842e-03 6.0904521e-04 9.9832708e-01]]
# predict class 2
# ************************************
# [[0.01501057 0.00359732 0.9813921 ]]
# predict class 2
# ************************************
# [[0.00228173 0.01215744 0.98556083]]
# predict class 2
# ************************************
# [[7.849476e-06 4.190723e-03 9.958014e-01]]
# predict class 2
# ************************************
# [[0.00242985 0.01041173 0.9871585 ]]
# predict class 2
# ************************************
# [[0.0644776  0.8519458  0.08357655]]
# predict class 1
# ************************************
# [[5.3187370e-05 9.9929786e-01 6.4895046e-04]]
# predict class 1
# ************************************
# [[6.508857e-05 9.998592e-01 7.562989e-05]]
# predict class 1
# ************************************
# [[0.09639931 0.8678367  0.03576393]]
# predict class 1
# ************************************
# [[0.2542282  0.08040052 0.6653713 ]]
# predict class 2
# ************************************
# [[0.03604753 0.00844085 0.9555117 ]]
# predict class 2
# ************************************
# [[0.14179493 0.189478   0.6687271 ]]
# predict class 2
# ************************************
# [[0.22710745 0.36651748 0.40637508]]
# predict class 2
# ************************************
# [[0.02257781 0.01320527 0.9642169 ]]
# predict class 2
# ************************************
# [[0.40090424 0.06810277 0.5309929 ]]
# predict class 2
# ************************************
# [[0.4194551  0.49217978 0.08836515]]
# predict class 1
# ************************************
# [[0.12611005 0.22336726 0.65052277]]
# predict class 2
# ************************************
# [[0.41107062 0.06433313 0.5245963 ]]
# predict class 2
# ************************************
# [[0.17039752 0.10585035 0.72375214]]
# predict class 2
# ************************************
# [[0.01474697 0.07691951 0.9083335 ]]
# predict class 2
# ************************************
# [[0.17515157 0.38203526 0.44281325]]
# predict class 2
# ************************************
# [[0.71172345 0.06658398 0.22169255]]
# predict class 0
# ************************************
# [[0.7559974  0.02822351 0.21577908]]
# predict class 0
# ************************************
# [[0.6490343  0.13153277 0.21943296]]
# predict class 0
# ************************************
# [[0.15275899 0.16290489 0.6843362 ]]
# predict class 2
# ************************************
# [[0.04084612 0.03744737 0.92170656]]
# predict class 2
# ************************************
# [[0.13684931 0.08738671 0.775764  ]]
# predict class 2
# ************************************
# [[0.1942329  0.02004524 0.7857219 ]]
# predict class 2
# ************************************
# [[0.1252007  0.08488422 0.7899151 ]]
# predict class 2
# ************************************
# [[0.02604185 0.2380777  0.7358805 ]]
# predict class 2
# ************************************
# [[0.1038738  0.12436873 0.7717575 ]]
# predict class 2
# ************************************
# [[0.8647635  0.04683128 0.08840529]]
# predict class 0
# ************************************
# [[0.49024302 0.4820251  0.02773195]]
# predict class 0
# ************************************
# [[0.24940418 0.23628144 0.51431435]]
# predict class 2
# ************************************
# [[0.02608081 0.00808712 0.96583205]]
# predict class 2
# ************************************
# [[0.06611206 0.04360576 0.89028215]]
# predict class 2
# ************************************
# [[0.0440122  0.22236621 0.7336216 ]]
# predict class 2
# ************************************
# [[0.15469487 0.7488118  0.09649342]]
# predict class 1
# ************************************
# [[0.43036094 0.08191668 0.48772243]]
# predict class 2
# ************************************
# [[0.29251876 0.02934097 0.67814034]]
# predict class 2
# ************************************
# [[0.03449086 0.0744824  0.89102674]]
# predict class 2
# ************************************
# [[0.00185613 0.01984623 0.97829765]]
# predict class 2
# ************************************
# [[0.00394671 0.01670612 0.97934717]]
# predict class 2
# ************************************
# [[0.09629735 0.18034786 0.72335476]]
# predict class 2
# ************************************
# [[0.5240349  0.02807309 0.447892  ]]
# predict class 0
# ************************************
# [[0.07425418 0.00427795 0.9214679 ]]
# predict class 2
# ************************************
# [[0.08379699 0.02321484 0.8929882 ]]
# predict class 2
# ************************************
# [[0.7333448  0.04300033 0.2236548 ]]
# predict class 0
# ************************************
# [[0.79202276 0.03371266 0.17426455]]
# predict class 0
# ...
# [[0.42190483 0.2650322  0.31306297]]
# predict class 0
# ************************************
# [[0.4577566  0.09233371 0.4499096 ]]
# predict class 0
# ************************************
# [[0.5852986  0.14853176 0.2661696 ]]
# predict class 0
# ************************************
# [[0.29265088 0.3255346  0.38181448]]
# predict class 2
# ************************************
# [[0.02243611 0.8833249  0.09423903]]
# predict class 1
# ************************************
# [[0.0240379  0.8902766  0.08568557]]
# predict class 1
# ************************************
# [[0.1151562  0.71256036 0.17228346]]
# predict class 1
# ************************************
# [[0.35491788 0.5435194  0.10156271]]
# predict class 1
# ************************************
# [[0.35512346 0.25246283 0.3924137 ]]
# predict class 2
# ************************************
# [[0.02453245 0.03153877 0.9439288 ]]
# predict class 2
# ************************************
# [[0.00681229 0.01945389 0.97373384]]
# predict class 2
# ************************************
# [[0.01937171 0.00646109 0.97416717]]
# predict class 2
# ************************************
# [[0.22203845 0.02859603 0.74936557]]
# predict class 2
# ************************************
# [[0.05995455 0.02681326 0.91323227]]
# predict class 2
# ************************************
# [[0.05899553 0.02974466 0.91125983]]
# predict class 2
# ************************************
# [[0.04451524 0.0244387  0.93104607]]
# predict class 2
# ************************************
# [[0.06262144 0.01070676 0.92667186]]
# predict class 2
# ************************************
# [[0.33800876 0.01313486 0.6488564 ]]
# predict class 2
# ************************************
# [[0.3773207  0.04274036 0.57993895]]
# predict class 2
# ************************************
# [[0.76529396 0.02094315 0.21376294]]
# predict class 0
# ************************************
# [[0.42884675 0.29447094 0.27668235]]
# predict class 0
# ************************************
# [[0.05949961 0.659653   0.28084737]]
# predict class 1
# ************************************
# [[0.5252081  0.04006602 0.43472594]]
# predict class 0
# ************************************
# [[0.2371869  0.00456756 0.7582455 ]]
# predict class 2
# ************************************
# [[0.05082088 0.0920187  0.8571604 ]]
# predict class 2
# ************************************
# [[0.04748221 0.7702858  0.18223199]]
# predict class 1
# ************************************
# [[0.07797239 0.89706546 0.02496209]]
# predict class 1
# ************************************
# [[0.36896256 0.52323157 0.10780582]]
# predict class 1
# ************************************
# [[0.6410059  0.12034921 0.23864487]]
# predict class 0
# ************************************
# [[0.08236598 0.07072054 0.8469134 ]]
# predict class 2
# ************************************
# [[0.05287507 0.44559914 0.50152576]]
# predict class 2
# ************************************
# [[0.08698326 0.7326735  0.18034324]]
# predict class 1
# ************************************
# [[0.0259815  0.44976246 0.524256  ]]
# predict class 2
# ************************************
# [[0.00718625 0.11960826 0.8732055 ]]
# predict class 2
# ************************************
# [[0.10848229 0.3804008  0.511117  ]]
# predict class 2
# ************************************
# [[0.04262998 0.15912952 0.7982406 ]]
# predict class 2
# ************************************
# [[0.1681078  0.5716412  0.26025108]]
# predict class 1
# ************************************
# [[0.5308811  0.2460838  0.22303511]]
# predict class 0
# ************************************
# [[0.6341679  0.04240639 0.32342568]]
# predict class 0
# ************************************
# [[0.9803813  0.00334996 0.01626871]]
# predict class 0
# ************************************
# [[0.88736486 0.00336855 0.10926662]]
# predict class 0
# ************************************
# [[0.6142191  0.01489263 0.3708882 ]]
# predict class 0
# ************************************
# [[0.4370302  0.11889946 0.4440703 ]]
# predict class 2
# ************************************
# [[0.11516608 0.02587195 0.858962  ]]
# predict class 2
# ************************************
# [[0.05678664 0.03485285 0.90836054]]
# predict class 2
# ************************************
# [[0.0101012  0.0048766  0.98502225]]
# predict class 2
# ************************************
# [[0.00248713 0.0013333  0.9961796 ]]
# predict class 2
# ************************************
# [[0.00322566 0.0012505  0.9955238 ]]
# predict class 2
# ************************************
# [[0.12241729 0.00246833 0.8751143 ]]
# predict class 2
# ************************************
# [[0.15919653 0.00662183 0.8341816 ]]
# predict class 2
# ************************************
# [[0.00628069 0.01009013 0.98362917]]
# predict class 2
# ************************************
# [[0.0117668  0.00419402 0.9840391 ]]
# predict class 2
# ************************************
# [[0.32383737 0.00926437 0.66689825]]
# predict class 2
# ************************************
# [[0.7704775  0.01920173 0.21032077]]
# predict class 0
# ************************************
# [[0.139042   0.00862875 0.8523292 ]]
# predict class 2
# ************************************
# [[0.06679952 0.00396972 0.9292307 ]]
# predict class 2
# ************************************
# [[0.16048232 0.00318947 0.8363282 ]]
# predict class 2
# ************************************
# [[0.23532626 0.08965962 0.6750141 ]]
# predict class 2
# ************************************
# [[0.24761723 0.48034135 0.27204147]]
# predict class 1
# ************************************
# [[0.62327796 0.01240566 0.36431646]]
# predict class 0
# ************************************
# [[0.75461525 0.00736152 0.23802324]]
# predict class 0
# ************************************
# [[0.20129642 0.41616777 0.38253585]]
# predict class 1
# ************************************
# [[0.01963569 0.8695139  0.11085027]]
# predict class 1
# ************************************
# [[0.03547372 0.6615602  0.3029661 ]]
# predict class 1
# ************************************
# [[0.14323804 0.12500367 0.7317583 ]]
# predict class 2
# ************************************
# [[0.309409   0.10124084 0.58935016]]
# predict class 2
# ************************************
# [[0.41412452 0.07409854 0.5117769 ]]
# predict class 2
# ************************************
# [[0.39946803 0.27728382 0.32324815]]
# predict class 0
# ************************************
# [[0.14480081 0.7647401  0.09045907]]
# predict class 1
# ************************************
# [[0.8585315  0.0335186  0.10794997]]
# predict class 0
# ************************************
# [[8.4660470e-01 4.8354192e-04 1.5291184e-01]]
# predict class 0
# ************************************
# [[0.57844657 0.00278407 0.41876933]]
# predict class 0
# ************************************
# [[0.20483787 0.2707995  0.52436256]]
# predict class 2
# ************************************
# [[0.04796091 0.91916865 0.03287037]]
# predict class 1
# ************************************
# [[0.65802    0.28423905 0.05774098]]
# predict class 0
# ************************************
# [[0.8009475  0.06101451 0.13803795]]
# predict class 0
# ************************************
# [[0.8435384  0.01210874 0.1443529 ]]
# predict class 0
# ************************************
# [[0.46787345 0.03164661 0.50048   ]]
# predict class 2
# ************************************
# [[0.48290795 0.03213192 0.4849601 ]]
# predict class 2
# ************************************
# [[0.46828526 0.03984554 0.49186915]]
# predict class 2
# ************************************
# [[0.30905813 0.28062516 0.41031674]]
# predict class 2
# ************************************
# [[0.41429037 0.05950166 0.526208  ]]
# predict class 2
# ************************************
# [[0.47390735 0.00517769 0.52091503]]
# predict class 2
# ************************************
# [[0.19977127 0.02254735 0.7776814 ]]
# predict class 2
# ************************************
# [[6.356966e-03 9.209121e-04 9.927221e-01]]
# predict class 2
# ************************************
# [[0.14238238 0.01814707 0.8394705 ]]
# predict class 2
# ************************************
# [[0.08867112 0.3210851  0.59024376]]
# predict class 2
# ************************************
# [[0.03307211 0.16281225 0.8041156 ]]
# predict class 2
# ************************************
# [[0.49409986 0.03664109 0.46925908]]
# predict class 0
# ************************************
# [[0.70561147 0.18955642 0.10483213]]
# predict class 0
# ************************************
# [[0.40062794 0.5510461  0.04832596]]
# predict class 1
# ************************************
# [[0.4192024  0.3323664  0.24843115]]
# predict class 0
# ************************************
# [[0.2828217  0.18079042 0.53638786]]
# predict class 2
# ************************************
# [[0.0807189  0.7289755  0.19030567]]
# predict class 1
# ************************************
# [[0.55958205 0.2070945  0.23332347]]
# predict class 0
# ************************************
# [[0.38895795 0.0144643  0.59657776]]
# predict class 2
# ************************************
# [[0.27681312 0.05825271 0.6649341 ]]
# predict class 2
# ************************************
# [[0.04012116 0.10361808 0.8562608 ]]
# predict class 2
# ************************************
# [[0.23167136 0.3686903  0.39963832]]
# predict class 2
# ************************************
# [[0.30594337 0.17350928 0.52054733]]
# predict class 2
# ************************************
# [[0.08668129 0.05603771 0.857281  ]]
# predict class 2
# ************************************
# [[0.58914983 0.07710955 0.33374065]]
# predict class 0
# ************************************
# [[0.46457574 0.07243439 0.46298987]]
# predict class 0
# ************************************
# [[0.31649736 0.05342327 0.6300794 ]]
# predict class 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\git\Senior_Thesis\try._realtime.ipynb Cell 2 line 1
#     <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W1sZmlsZQ%3D%3D?line=115'>116</a> train_cwt_stack = call_pywt(new_data)
#     <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W1sZmlsZQ%3D%3D?line=117'>118</a> # print("*****************CWT*******************")
#     <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W1sZmlsZQ%3D%3D?line=118'>119</a> # print(train_cwt_stack)
# --> <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W1sZmlsZQ%3D%3D?line=121'>122</a> y_pred_raw = pretrained_model.predict(train_cwt_stack ,verbose=False)
#     <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W1sZmlsZQ%3D%3D?line=123'>124</a> # Append the predicted class to the real-time plot data
#     <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W1sZmlsZQ%3D%3D?line=124'>125</a> # x_vals.append(time_all)
#     <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W1sZmlsZQ%3D%3D?line=125'>126</a> # y_vals.append(np.argmax(y_pred_raw))
#     <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W1sZmlsZQ%3D%3D?line=127'>128</a> print("************************************")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\training.py:2521, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2512     except ValueError:
#    2513         warnings.warn(
#    2514             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2515             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2518             stacklevel=2,
#    2519         )
# -> 2521 data_handler = data_adapter.get_data_handler(
#    2522     x=x,
#    2523     batch_size=batch_size,
#    2524     steps_per_epoch=steps,
#    2525     initial_epoch=0,
#    2526     epochs=1,
#    2527     max_queue_size=max_queue_size,
#    2528     workers=workers,
#    2529     use_multiprocessing=use_multiprocessing,
#    2530     model=self,
#    2531     steps_per_execution=self._steps_per_execution,
#    2532 )
#    2534 # Container that configures and calls `tf.keras.Callback`s.
#    2535 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\data_adapter.py:1678, in get_data_handler(*args, **kwargs)
#    1676         return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1677     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1678 return DataHandler(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\data_adapter.py:1285, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1282     self._steps_per_execution = steps_per_execution
#    1284 adapter_cls = select_data_adapter(x, y)
# -> 1285 self._adapter = adapter_cls(
#    1286     x,
#    1287     y,
#    1288     batch_size=batch_size,
#    1289     steps=steps_per_epoch,
#    1290     epochs=epochs - initial_epoch,
#    1291     sample_weights=sample_weight,
#    1292     shuffle=shuffle,
#    1293     max_queue_size=max_queue_size,
#    1294     workers=workers,
#    1295     use_multiprocessing=use_multiprocessing,
#    1296     distribution_strategy=tf.distribute.get_strategy(),
#    1297     model=model,
#    1298     pss_evaluation_shards=pss_evaluation_shards,
#    1299 )
#    1301 strategy = tf.distribute.get_strategy()
#    1303 self._current_step = 0
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\data_adapter.py:353, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     350         flat_dataset = flat_dataset.shuffle(1024).repeat(epochs)
#     351     return flat_dataset
# --> 353 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     355 dataset = self.slice_inputs(indices_dataset, inputs)
#     357 if shuffle == "batch":
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\data\ops\dataset_ops.py:2323, in DatasetV2.flat_map(self, map_func, name)
#    2319 # Loaded lazily due to a circular dependency (dataset_ops -> flat_map_op ->
#    2320 # dataset_ops).
#    2321 # pylint: disable=g-import-not-at-top,protected-access
#    2322 from tensorflow.python.data.ops import flat_map_op
# -> 2323 return flat_map_op._flat_map(self, map_func, name=name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\data\ops\flat_map_op.py:24, in _flat_map(input_dataset, map_func, name)
#      22 def _flat_map(input_dataset, map_func, name=None):  # pylint: disable=unused-private-name
#      23   """See `Dataset.flat_map()` for details."""
# ---> 24   return _FlatMapDataset(input_dataset, map_func, name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\data\ops\flat_map_op.py:42, in _FlatMapDataset.__init__(self, input_dataset, map_func, name)
#      40 self._structure = self._map_func.output_structure._element_spec
#      41 self._name = name
# ---> 42 variant_tensor = gen_dataset_ops.flat_map_dataset(
#      43     input_dataset._variant_tensor,  # pylint: disable=protected-access
#      44     self._map_func.function.captured_inputs,
#      45     f=self._map_func.function,
#      46     **self._common_args)
#      47 super().__init__(input_dataset, variant_tensor)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\ops\gen_dataset_ops.py:2387, in flat_map_dataset(input_dataset, other_arguments, f, output_types, output_shapes, metadata, name)
#    2385 if tld.is_eager:
#    2386   try:
# -> 2387     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    2388       _ctx, "FlatMapDataset", name, input_dataset, other_arguments, "f", f,
#    2389       "output_types", output_types, "output_shapes", output_shapes,
#    2390       "metadata", metadata)
#    2391     return _result
#    2392   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# # CSP+LDA

# %%
# from pylsl import StreamInlet, resolve_stream
# import numpy as np
# import matplotlib.pyplot as plt
# import mne
# import pickle
# from sklearn.metrics import confusion_matrix
# import seaborn as sns
# from matplotlib.animation import FuncAnimation


# epoch_2s = np.zeros(shape=(7,501))

# print("looking for an EEG stream...")
# streams = resolve_stream()
# print(streams)

# data = []
# time_count = 0.0
# time_all = 0.0
# time_interval = 0.1

# inlet = StreamInlet(streams[0])

# fs = 250.0
 
# channels = ["Fz","C3", "Cz", "C4","Pz","PO7","PO8"]

# info = mne.create_info(
#     ch_names= channels,
#     ch_types= ['eeg']*len(channels),
#     sfreq= fs
# )

# while True:
#     sample, timestamp = inlet.pull_sample()
#     # print(sample)

#     if timestamp:
#         data1 = sample[0:6]
#         data1.append(sample[7])
#         data.append(data1)  

#         time_count += 1 * 0.004
#         time_count = np.round(time_count ,3)
#         time_all += 1 * 0.004

#         if time_count == time_interval:

#             data = np.asarray(data)
#             epoch_2s = np.delete(epoch_2s, slice(0,int(time_interval/0.004)), axis =1)
#             epoch_2s = np.append(epoch_2s, data.T, axis= 1)
            

#             raw = mne.EpochsArray(epoch_2s.reshape(1,7,501), info, verbose=False)
#             eeg1 = raw.copy().filter(l_freq=6.0, h_freq=32.0, method = 'iir', iir_params= {"order": 5, "ftype":'butter'}, verbose = False)
#             eeg1 = eeg1.copy().set_eeg_reference(ref_channels="average", verbose=False)
            

#             with open('trained_csp2_model.pkl', 'rb') as file:
#                 trained_csp2 = pickle.load(file)
#             new_data2 = trained_csp2.transform(eeg1.get_data().reshape(1,7,501))


#             with open('trained_lda_model.pkl', 'rb') as file:
#                 trained_lda = pickle.load(file)

#             print(trained_lda.predict(new_data2))

#             if trained_lda.predict(new_data2)[0] == 6:
#                 print('class predict LEFT')
#             elif trained_lda.predict(new_data2)[0] == 7:
#                 print('class predict RIGHT')
#             elif trained_lda.predict(new_data2)[0] == 9:
#                 print('class predict NON-MI')
#             else:
#                 print('class predict UP')
        
#             data = np.ndarray.tolist(data)
#             data = []
#             time_count = 0.0
# Out:
# looking for an EEG stream...
# [<pylsl.pylsl.StreamInfo object at 0x00000161D5EEB350>, <pylsl.pylsl.StreamInfo object at 0x00000161D3998E10>]
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [8]
# class predict UP
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [8]
# class predict UP
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [6]
# class predict LEFT
# [6]
# class predict LEFT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [8]
# class predict UP
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [8]
# class predict UP
# [8]
# class predict UP
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [7]
# class predict RIGHT
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# [9]
# class predict NON-MI
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\git\Senior_Thesis\try._realtime.ipynb Cell 6 line 5
#      <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W3sZmlsZQ%3D%3D?line=49'>50</a> epoch_2s = np.delete(epoch_2s, slice(0,int(time_interval/0.004)), axis =1)
#      <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W3sZmlsZQ%3D%3D?line=50'>51</a> epoch_2s = np.append(epoch_2s, data.T, axis= 1)
# ---> <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W3sZmlsZQ%3D%3D?line=53'>54</a> raw = mne.EpochsArray(epoch_2s.reshape(1,7,501), info, verbose=False)
#      <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W3sZmlsZQ%3D%3D?line=54'>55</a> eeg1 = raw.copy().filter(l_freq=6.0, h_freq=32.0, method = 'iir', iir_params= {"order": 5, "ftype":'butter'}, verbose = False)
#      <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W3sZmlsZQ%3D%3D?line=55'>56</a> eeg1 = eeg1.copy().set_eeg_reference(ref_channels="average", verbose=False)
#
# File <decorator-gen-290>:10, in __init__(self, data, info, events, tmin, event_id, reject, flat, reject_tmin, reject_tmax, baseline, proj, on_missing, metadata, selection, drop_log, raw_sfreq, verbose)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mne\epochs.py:3276, in EpochsArray.__init__(self, data, info, events, tmin, event_id, reject, flat, reject_tmin, reject_tmax, baseline, proj, on_missing, metadata, selection, drop_log, raw_sfreq, verbose)
#    3273 info = info.copy()  # do not modify original info
#    3274 tmax = (data.shape[2] - 1) / info["sfreq"] + tmin
# -> 3276 super(EpochsArray, self).__init__(
#    3277     info,
#    3278     data,
#    3279     events,
#    3280     event_id,
#    3281     tmin,
#    3282     tmax,
#    3283     baseline,
#    3284     reject=reject,
#    3285     flat=flat,
#    3286     reject_tmin=reject_tmin,
#    3287     reject_tmax=reject_tmax,
#    3288     decim=1,
#    3289     metadata=metadata,
#    3290     selection=selection,
#    3291     proj=proj,
#    3292     on_missing=on_missing,
#    3293     drop_log=drop_log,
#    3294     raw_sfreq=raw_sfreq,
#    3295     verbose=verbose,
#    3296 )
#    3297 if self.baseline is not None:
#    3298     self._do_baseline = True
#
# File <decorator-gen-274>:10, in __init__(self, info, data, events, event_id, tmin, tmax, baseline, raw, picks, reject, flat, decim, reject_tmin, reject_tmax, detrend, proj, on_missing, preload_at_end, selection, drop_log, filename, metadata, event_repeated, raw_sfreq, annotations, verbose)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mne\epochs.py:618, in BaseEpochs.__init__(***failed resolving arguments***)
#     616 start_idx = int(round(tmin * sfreq))
#     617 self._raw_times = np.arange(start_idx, int(round(tmax * sfreq)) + 1) / sfreq
# --> 618 self._set_times(self._raw_times)
#     620 # check reject_tmin and reject_tmax
#     621 if reject_tmin is not None:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mne\utils\mixin.py:490, in TimeMixin._set_times(self, times)
#     487     """Time vector in seconds."""
#     488     return self._times_readonly
# --> 490 def _set_times(self, times):
#     491     """Set self._times_readonly (and make it read only)."""
#     492     # naming used to indicate that it shouldn't be
#     493     # changed directly, but rather via this method
#
# KeyboardInterrupt:
