# %%
from pylsl import StreamInlet, resolve_stream
import numpy as np
from scipy.fft import fft2, fftshift
import matplotlib.pyplot as plt
from scipy.signal import butter, lfilter
from scipy.signal import welch
import mne
import pywt
import pickle
import keras
from keras.models import load_model
from sklearn.metrics import confusion_matrix
import seaborn as sns

pretrained_model = load_model("CNN_MIexe_model_weights.h5")

epoch_2s = np.zeros(shape=(7,501))

# first resolve an EEG stream on the lab network
print("looking for an EEG stream...")
streams = resolve_stream()
print(streams)

data = []
time_count = 0.0
time_all = 0.0

# create a new inlet to read from the stream
inlet = StreamInlet(streams[0])

fs = 250.0
 
channels = ["Fz","C3", "Cz", "C4","Pz","PO7","PO8"]

info = mne.create_info(
    ch_names= channels,
    ch_types= ['eeg']*len(channels),
    sfreq= fs
)

def call_pywt(new_data):
    component_num = 7
    train_cwt = np.ndarray(shape=(new_data.shape[0], new_data.shape[2], component_num))
    for jj in range(0, new_data.shape[0]):
        train_cwt[jj] = new_data[jj].T
    print(np.shape(new_data))

    scales = range(1,31)

    waveletname = 'morl'
    train_size = new_data.shape[0]
    train_data_cwt = np.ndarray(shape=(train_size, len(scales), new_data.shape[2], component_num))

    for ii in range(0,train_size):
        if ii % 40 == 0:
            print(ii)
        for jj in range(0,component_num):
            signal = train_cwt[ii, :, jj]
            coeff, _ = pywt.cwt(signal, scales, waveletname, 1)
            coeff_ = coeff[:,:new_data.shape[2]]  #crop 227 sample for each channel
            train_data_cwt[ii, :, :, jj] = coeff_
    print(np.shape(train_data_cwt))

    # Stack array and convert to image
    from PIL import Image as im 
    train_cwt_stack = np.ndarray(shape=(train_size, len(scales)*component_num, new_data.shape[2]))

    for jj in range(0,train_data_cwt.shape[0]):
        train_cwt_stack[jj] = np.vstack((train_data_cwt[jj,:,:,0], train_data_cwt[jj,:,:,1], train_data_cwt[jj,:,:,2], train_data_cwt[jj,:,:,3], train_data_cwt[jj,:,:,4], train_data_cwt[jj,:,:,5], train_data_cwt[jj,:,:,6]))
    return train_cwt_stack


while True:
    # get a new sample (you can also omit the timestamp part if you're not
    # interested in it)
    sample, timestamp = inlet.pull_sample()
    # print(sample)

    if timestamp:
        data1 = sample[0:6]
        data1.append(sample[7])
        data.append(data1)

        time_count += 1 * 0.004
        time_count = np.round(time_count ,3)
        time_all += 1 * 0.004

        if time_count == 2.004:

            # data = np.asarray(data)
            # epoch_2s = np.delete(epoch_2s, slice(0,25), axis =1)
            # epoch_2s = np.append(epoch_2s, data.T, axis= 1)

            # print(epoch_2s)

            data = np.asarray(data)
            data = np.transpose(data)
            epoch_2s = data
            # print(epoch_2s)
            
            raw = mne.io.RawArray(epoch_2s, info)
            eeg1 = raw.copy().filter(l_freq=1.0, h_freq=30.0, method = 'iir', iir_params= {"order": 5, "ftype":'butter'})
            eeg1 = eeg1.copy().set_eeg_reference(ref_channels="average")

            # print(np.shape(eeg1.get_data()))
            # print("*****************raw 2 seconds*******************")
            # print(eeg1.get_data())

            with open('trained_csp_model.pkl', 'rb') as file:
                trained_csp = pickle.load(file)

            new_data = trained_csp.transform(eeg1.get_data().reshape(1,7,501))

            # print("*****************CSP*******************")
            # print(new_data)

            train_cwt_stack = call_pywt(new_data)

            # print("*****************CWT*******************")
            # print(train_cwt_stack)

            y_pred_raw = pretrained_model.predict(train_cwt_stack)

            print("************************************")
            print(y_pred_raw)
            print("predict class", np.argmax(y_pred_raw))
        
            data = np.ndarray.tolist(data)
            data = []
            time_count = 0.0
        
        # if time_all >= 10:
        #     break
# Out:
# looking for an EEG stream...
# [<pylsl.pylsl.StreamInfo object at 0x000001F33CDF1C50>, <pylsl.pylsl.StreamInfo object at 0x000001F3099DA710>, <pylsl.pylsl.StreamInfo object at 0x000001F3099D8E50>]
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 121ms/step
# ************************************
# [[0.07631462 0.09174915 0.32023987 0.51169634]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 43ms/step
# ************************************
# [[0.71448374 0.00195458 0.0066697  0.2768919 ]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.35917264 0.43788725 0.11040059 0.09253959]]
# predict class 1
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.26201943 0.15842558 0.0282047  0.5513503 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 39ms/step
# ************************************
# [[0.67085296 0.1610387  0.00753777 0.16057056]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 39ms/step
# ************************************
# [[0.16353425 0.7436174  0.0320866  0.06076181]]
# predict class 1
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.6215117  0.19505152 0.0071492  0.17628758]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.6070351  0.2709788  0.02135107 0.10063502]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.01017705 0.11326556 0.25522482 0.6213325 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.03831664 0.52024597 0.35728592 0.08415148]]
# predict class 1
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.1787718  0.36400902 0.0017953  0.45542383]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.05556516 0.20771775 0.18913685 0.54758024]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.3070237  0.18452606 0.17292301 0.33552718]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.19688062 0.09524699 0.0582724  0.64959997]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.07829776 0.10703535 0.00920353 0.8054634 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.12088431 0.30818185 0.07510541 0.4958285 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.4083393  0.16983736 0.13255702 0.28926635]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.0708577  0.54236543 0.00153605 0.38524088]]
# predict class 1
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.00731275 0.8922944  0.02118006 0.07921274]]
# predict class 1
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.04333502 0.01821832 0.24048771 0.69795895]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.02804501 0.01031597 0.02195091 0.9396881 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.00400112 0.51042277 0.01616094 0.46941516]]
# predict class 1
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.5051549  0.05025971 0.23093763 0.21364778]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.17735438 0.00661388 0.18661328 0.62941843]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.3838673  0.25098112 0.26654646 0.09860515]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.18600522 0.30684707 0.07217598 0.43497172]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.0040668  0.03782657 0.02125501 0.9368516 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 39ms/step
# ************************************
# [[0.00693016 0.88757557 0.03070918 0.07478508]]
# predict class 1
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.2198964  0.39344817 0.03343883 0.35321653]]
# predict class 1
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.00583409 0.41218293 0.531296   0.05068696]]
# predict class 2
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.04487385 0.68873864 0.03990974 0.22647774]]
# predict class 1
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.48612657 0.16303253 0.03131544 0.31952548]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.0055405  0.37052637 0.02745817 0.5964749 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.28017846 0.39164147 0.30730343 0.02087664]]
# predict class 1
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.25735474 0.11413731 0.09831179 0.5301962 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.10811177 0.06452915 0.1864764  0.6408827 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 35ms/step
# ************************************
# [[0.29732886 0.06469958 0.18833391 0.44963768]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.64269304 0.03636729 0.2573112  0.06362851]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.49531123 0.02052777 0.31023526 0.17392573]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.01128333 0.04750955 0.76142055 0.17978661]]
# predict class 2
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.11574112 0.02405846 0.84964305 0.01055739]]
# predict class 2
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.07998146 0.04669186 0.28468516 0.5886415 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.05456474 0.1479823  0.77122504 0.02622793]]
# predict class 2
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.01770221 0.00799711 0.65165836 0.32264233]]
# predict class 2
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.01735782 0.00281785 0.7792873  0.2005371 ]]
# predict class 2
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 39ms/step
# ************************************
# [[0.01302557 0.0041997  0.05014062 0.9326342 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.01451594 0.00290704 0.34658507 0.63599193]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.18347466 0.13217068 0.28652924 0.39782542]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.30330414 0.03579189 0.12312791 0.53777605]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.37682924 0.07838371 0.25831148 0.2864755 ]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.15789348 0.26573348 0.1189996  0.45737335]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.35867992 0.21874586 0.32848656 0.09408764]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.45970446 0.06133557 0.06383754 0.41512248]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.05441508 0.08793122 0.354316   0.50333774]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.01161994 0.08187325 0.83128464 0.07522219]]
# predict class 2
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.7201642  0.13731486 0.03070541 0.11181559]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.0878875  0.00940954 0.31627584 0.58642715]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.02417224 0.3514017  0.06474269 0.5596834 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.00109751 0.45487732 0.08573378 0.4582914 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.08926797 0.09194907 0.06030512 0.75847787]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.38070884 0.00961867 0.02740645 0.5822661 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.05199343 0.33997706 0.14373837 0.46429113]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.01958888 0.32944757 0.00664318 0.6443204 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.33297262 0.23912409 0.03442333 0.3934799 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.17863071 0.10464203 0.078102   0.6386252 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# ...
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.00405804 0.03195997 0.03680684 0.92717505]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.01716558 0.08195504 0.08290643 0.8179729 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.24866737 0.0827504  0.4845556  0.18402666]]
# predict class 2
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.1589297  0.21856628 0.07488031 0.5476237 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.00907794 0.02358663 0.4075091  0.55982643]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.01372583 0.00188018 0.7773616  0.20703246]]
# predict class 2
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.46130377 0.13987975 0.11108887 0.28772756]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.05743064 0.01512742 0.21098211 0.7164598 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 36ms/step
# ************************************
# [[0.0167346  0.08301109 0.82726127 0.07299308]]
# predict class 2
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.28303936 0.41709027 0.02930155 0.2705688 ]]
# predict class 1
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.03102551 0.08558881 0.04090036 0.84248537]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.34118798 0.16273183 0.35260713 0.14347304]]
# predict class 2
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.14666285 0.09794641 0.22862212 0.5267686 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.35415965 0.33191234 0.21189404 0.10203391]]
# predict class 0
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[0.05549868 0.04792186 0.17466807 0.7219114 ]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.01677    0.00436916 0.92475563 0.05410524]]
# predict class 2
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 37ms/step
# ************************************
# [[4.3871538e-03 7.2453683e-04 2.6705796e-01 7.2783029e-01]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 38ms/step
# ************************************
# [[0.26822636 0.01709811 0.04345581 0.67121965]]
# predict class 3
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 35ms/step
# ************************************
# [[0.27782264 0.01312123 0.476347   0.23270915]]
# predict class 2
# Creating RawArray with float64 data, n_channels=7, n_times=501
#     Range : 0 ... 500 =      0.000 ...     2.000 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 20 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
#
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# (1, 7, 501)
# 0
# (1, 30, 501, 7)
# 1/1 [==============================] - 0s 45ms/step
# ************************************
# [[0.18382946 0.05494899 0.04782321 0.7133984 ]]
# predict class 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\git\Senior_Thesis\try._realtime.ipynb Cell 1 line 7
#      <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W0sZmlsZQ%3D%3D?line=69'>70</a>     return train_cwt_stack
#      <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W0sZmlsZQ%3D%3D?line=72'>73</a> while True:
#      <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W0sZmlsZQ%3D%3D?line=73'>74</a>     # get a new sample (you can also omit the timestamp part if you're not
#      <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W0sZmlsZQ%3D%3D?line=74'>75</a>     # interested in it)
# ---> <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W0sZmlsZQ%3D%3D?line=75'>76</a>     sample, timestamp = inlet.pull_sample()
#      <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W0sZmlsZQ%3D%3D?line=76'>77</a>     # print(sample)
#      <a href='vscode-notebook-cell:/c%3A/git/Senior_Thesis/try._realtime.ipynb#W0sZmlsZQ%3D%3D?line=78'>79</a>     if timestamp:
#
# File c:\Python311\Lib\site-packages\pylsl\pylsl.py:803, in StreamInlet.pull_sample(self, timeout, sample)
#     800     assign_to = None
#     802 errcode = c_int()
# --> 803 timestamp = self.do_pull_sample(self.obj, byref(self.sample),
#     804                                 self.channel_count, c_double(timeout),
#     805                                 byref(errcode))
#     806 handle_error(errcode)
#     807 if timestamp:
#
# KeyboardInterrupt:
