# %%
import mne
import numpy as np
from mne.datasets import eegbci
from mne.channels import make_standard_montage
import sys
import matplotlib.pyplot as plt

run = [0] * 5
raw1sub = [0] * 10
for j in range (2,12):
    for i in range (0,5):
        run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
    raw1sub[j-2] = mne.concatenate_raws(run)
    
raw = mne.concatenate_raws([raw1sub[0]])
# raw = mne.concatenate_raws(raw1sub)

eegbci.standardize(raw)  # set channel names
montage = make_standard_montage("standard_1005") 
raw.set_montage(montage)
# Out:
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-02\eeg\sub-02_task-MIvsRest_run-0_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15624  =      0.000 ...   124.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-02\eeg\sub-02_task-MIvsRest_run-1_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 55874  =      0.000 ...   446.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-02\eeg\sub-02_task-MIvsRest_run-2_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54624  =      0.000 ...   436.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-02\eeg\sub-02_task-MIvsRest_run-3_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 42374  =      0.000 ...   338.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-02\eeg\sub-02_task-MIvsRest_run-4_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 53874  =      0.000 ...   430.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-03\eeg\sub-03_task-MIvsRest_run-0_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15999  =      0.000 ...   127.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-03\eeg\sub-03_task-MIvsRest_run-1_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 53499  =      0.000 ...   427.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-03\eeg\sub-03_task-MIvsRest_run-2_eeg.edf...
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54999  =      0.000 ...   439.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-03\eeg\sub-03_task-MIvsRest_run-3_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 55124  =      0.000 ...   440.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-03\eeg\sub-03_task-MIvsRest_run-4_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 55874  =      0.000 ...   446.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-04\eeg\sub-04_task-MIvsRest_run-0_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15749  =      0.000 ...   125.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-04\eeg\sub-04_task-MIvsRest_run-1_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 55874  =      0.000 ...   446.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-04\eeg\sub-04_task-MIvsRest_run-2_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54124  =      0.000 ...   432.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-04\eeg\sub-04_task-MIvsRest_run-3_eeg.edf...
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54749  =      0.000 ...   437.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-04\eeg\sub-04_task-MIvsRest_run-4_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54124  =      0.000 ...   432.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-05\eeg\sub-05_task-MIvsRest_run-0_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15749  =      0.000 ...   125.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-05\eeg\sub-05_task-MIvsRest_run-1_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 53999  =      0.000 ...   431.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-05\eeg\sub-05_task-MIvsRest_run-2_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 55499  =      0.000 ...   443.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-05\eeg\sub-05_task-MIvsRest_run-3_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 55374  =      0.000 ...   442.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-05\eeg\sub-05_task-MIvsRest_run-4_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54124  =      0.000 ...   432.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-06\eeg\sub-06_task-MIvsRest_run-0_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15624  =      0.000 ...   124.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-06\eeg\sub-06_task-MIvsRest_run-1_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54999  =      0.000 ...   439.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-06\eeg\sub-06_task-MIvsRest_run-2_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54624  =      0.000 ...   436.992 secs...
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-06\eeg\sub-06_task-MIvsRest_run-3_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 56249  =      0.000 ...   449.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-06\eeg\sub-06_task-MIvsRest_run-4_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54624  =      0.000 ...   436.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-07\eeg\sub-07_task-MIvsRest_run-0_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15624  =      0.000 ...   124.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-07\eeg\sub-07_task-MIvsRest_run-1_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 53499  =      0.000 ...   427.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-07\eeg\sub-07_task-MIvsRest_run-2_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 53249  =      0.000 ...   425.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-07\eeg\sub-07_task-MIvsRest_run-3_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54374  =      0.000 ...   434.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-07\eeg\sub-07_task-MIvsRest_run-4_eeg.edf...
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 53874  =      0.000 ...   430.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-08\eeg\sub-08_task-MIvsRest_run-0_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15749  =      0.000 ...   125.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-08\eeg\sub-08_task-MIvsRest_run-1_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54999  =      0.000 ...   439.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-08\eeg\sub-08_task-MIvsRest_run-2_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 55374  =      0.000 ...   442.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-08\eeg\sub-08_task-MIvsRest_run-3_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 55124  =      0.000 ...   440.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-08\eeg\sub-08_task-MIvsRest_run-4_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54374  =      0.000 ...   434.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-09\eeg\sub-09_task-MIvsRest_run-0_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15749  =      0.000 ...   125.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-09\eeg\sub-09_task-MIvsRest_run-1_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 55499  =      0.000 ...   443.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-09\eeg\sub-09_task-MIvsRest_run-2_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 55124  =      0.000 ...   440.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-09\eeg\sub-09_task-MIvsRest_run-3_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# Reading 0 ... 55374  =      0.000 ...   442.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-09\eeg\sub-09_task-MIvsRest_run-4_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54124  =      0.000 ...   432.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-010\eeg\sub-010_task-MIvsRest_run-0_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15749  =      0.000 ...   125.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-010\eeg\sub-010_task-MIvsRest_run-1_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54124  =      0.000 ...   432.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-010\eeg\sub-010_task-MIvsRest_run-2_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 55999  =      0.000 ...   447.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-010\eeg\sub-010_task-MIvsRest_run-3_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 53999  =      0.000 ...   431.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-010\eeg\sub-010_task-MIvsRest_run-4_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54624  =      0.000 ...   436.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-011\eeg\sub-011_task-MIvsRest_run-0_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 15749  =      0.000 ...   125.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-011\eeg\sub-011_task-MIvsRest_run-1_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54374  =      0.000 ...   434.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-011\eeg\sub-011_task-MIvsRest_run-2_eeg.edf...
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54374  =      0.000 ...   434.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-011\eeg\sub-011_task-MIvsRest_run-3_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 54499  =      0.000 ...   435.992 secs...
# Extracting EDF parameters from D:\Low-cost EEG dataset\sub-011\eeg\sub-011_task-MIvsRest_run-4_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 53874  =      0.000 ...   430.992 secs...
# C:\Users\pipo_\AppData\Local\Temp\ipykernel_15680\2902485083.py:12: RuntimeWarning: Omitted 1 annotation(s) that were outside data range.
#   run[i] = mne.io.read_raw_edf("D:\Low-cost EEG dataset\sub-0"+str(j)+"\eeg\sub-0"+str(j)+"_task-MIvsRest_run-"+ str(i) +"_eeg.edf",preload = True)
# <RawEDF | sub-02_task-MIvsRest_run-0_eeg.edf, 15 x 222375 (1779.0 s), ~25.5 MB, data loaded>

# %%
events_raw, event_dict = mne.events_from_annotations(raw)
epochs = mne.Epochs(raw, events_raw, 
        tmin=-1.5,     # init timestamp of epoch (0 means trigger timestamp same as event start)
        tmax=4.0,    # final timestamp (10 means set epoch duration 10 second)
        event_id= event_dict,
        preload = True,
        event_repeated='drop'
    )
# Out:
# Used Annotations descriptions: ['OVTK_GDF_Correct', 'OVTK_GDF_Cross_On_Screen', 'OVTK_GDF_End_Of_Session', 'OVTK_GDF_End_Of_Trial', 'OVTK_GDF_Feedback_Continuous', 'OVTK_GDF_Incorrect', 'OVTK_GDF_Right', 'OVTK_GDF_Start_Of_Trial', 'OVTK_GDF_Tongue', 'OVTK_StimulationId_BaselineStart', 'OVTK_StimulationId_BaselineStop', 'OVTK_StimulationId_Beep', 'OVTK_StimulationId_ExperimentStart', 'OVTK_StimulationId_ExperimentStop', 'OVTK_StimulationId_Train']
# Multiple event values for single event times found. Keeping the first occurrence and dropping all others.
# Not setting metadata
# 697 matching events found
# Setting baseline interval to [-1.504, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 697 events and 689 original time points ...
# 12 bad epochs dropped

# %%
epochs
# Out:
# <Epochs |  685 events (all good), -1.504 - 4 sec, baseline -1.504 – 0 sec, ~54.0 MB, data loaded,
#  'OVTK_GDF_Correct': 11
#  'OVTK_GDF_End_Of_Session': 4
#  'OVTK_GDF_Feedback_Continuous': 160
#  'OVTK_GDF_Incorrect': 20
#  'OVTK_GDF_Right': 80
#  'OVTK_GDF_Start_Of_Trial': 160
#  'OVTK_GDF_Tongue': 80
#  'OVTK_StimulationId_BaselineStart': 5
#  'OVTK_StimulationId_BaselineStop': 5
#  'OVTK_StimulationId_Beep': 160
#  and 3 more events ...>

# %%
from IPython.display import Image
Image('D:\Low-cost EEG dataset\Discription.png')

# %% [markdown]
# # MCRP

# %%
eeg1 = raw.copy().filter(l_freq=0.05, h_freq=3.0, method = 'iir', iir_params= {"order": 12, "ftype":'butter'})
eeg1 = eeg1.copy().set_eeg_reference(ref_channels="average")

eeg1= eeg1.pick_channels(['C3','Cz','C4'])
events, _ = mne.events_from_annotations(eeg1)
event_ids = dict(Right=7, Tongue=9)

epochs = mne.Epochs(eeg1, events, 
        tmin=-2.0,     # init timestamp of epoch (0 means trigger timestamp same as event start)
        tmax=4.0,    # final timestamp (10 means set epoch duration 10 second)
        event_id= event_ids,
        preload = True,
        event_repeated='drop'
    )
# Out:
# Filtering raw data in 5 contiguous segments
# Setting up band-pass filter from 0.05 - 3 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 48 (effective, after forward-backward)
# - Cutoffs at 0.05, 3.00 Hz: -6.02, -6.02 dB
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Used Annotations descriptions: ['OVTK_GDF_Correct', 'OVTK_GDF_Cross_On_Screen', 'OVTK_GDF_End_Of_Session', 'OVTK_GDF_End_Of_Trial', 'OVTK_GDF_Feedback_Continuous', 'OVTK_GDF_Incorrect', 'OVTK_GDF_Right', 'OVTK_GDF_Start_Of_Trial', 'OVTK_GDF_Tongue', 'OVTK_StimulationId_BaselineStart', 'OVTK_StimulationId_BaselineStop', 'OVTK_StimulationId_Beep', 'OVTK_StimulationId_ExperimentStart', 'OVTK_StimulationId_ExperimentStop', 'OVTK_StimulationId_Train']
# Not setting metadata
# 160 matching events found
# Setting baseline interval to [-2.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 160 events and 751 original time points ...
# 0 bad epochs dropped

# %%
epochs
# Out:
# <Epochs |  160 events (all good), -2 - 4 sec, baseline -2 – 0 sec, ~2.8 MB, data loaded,
#  'Right': 80
#  'Tongue': 80>

# %%
epochs['Right'].average().plot() # imagery hand movement
epochs['Tongue'].average().plot() # non imagery
print('...')
# Out:
# ...

# %% [markdown]
# # ERDS

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import TwoSlopeNorm
import pandas as pd
import seaborn as sns
import mne
from mne.datasets import eegbci
from mne.io import concatenate_raws, read_raw_edf
from mne.time_frequency import tfr_multitaper
from mne.stats import permutation_cluster_1samp_test as pcluster_test

# %%
eeg1 = raw.copy().filter(l_freq=2.0, h_freq=36.0, method = 'iir', iir_params= {"order": 12, "ftype":'butter'})
eeg1 = eeg1.copy().set_eeg_reference(ref_channels="average")

eeg1= eeg1.pick_channels(['C3','Cz','C4'])
events, _ = mne.events_from_annotations(eeg1)
event_ids = dict(Right=7, Tongue=9)

epochs = mne.Epochs(eeg1, events, 
        tmin=-2.0,     # init timestamp of epoch (0 means trigger timestamp same as event start)
        tmax=4.5,    # final timestamp (10 means set epoch duration 10 second)
        event_id= event_ids,
        preload = True,
        event_repeated='drop'
    )
# Out:
# Filtering raw data in 5 contiguous segments
# Setting up band-pass filter from 2 - 36 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 48 (effective, after forward-backward)
# - Cutoffs at 2.00, 36.00 Hz: -6.02, -6.02 dB
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Used Annotations descriptions: ['OVTK_GDF_Correct', 'OVTK_GDF_Cross_On_Screen', 'OVTK_GDF_End_Of_Session', 'OVTK_GDF_End_Of_Trial', 'OVTK_GDF_Feedback_Continuous', 'OVTK_GDF_Incorrect', 'OVTK_GDF_Right', 'OVTK_GDF_Start_Of_Trial', 'OVTK_GDF_Tongue', 'OVTK_StimulationId_BaselineStart', 'OVTK_StimulationId_BaselineStop', 'OVTK_StimulationId_Beep', 'OVTK_StimulationId_ExperimentStart', 'OVTK_StimulationId_ExperimentStop', 'OVTK_StimulationId_Train']
# Not setting metadata
# 160 matching events found
# Setting baseline interval to [-2.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 160 events and 813 original time points ...
# 0 bad epochs dropped

# %%
freqs = np.arange(2, 36)  # frequencies from 2-35Hz
vmin, vmax = -0.5, 1.0  # set min and max ERDS values in plot
baseline = (-1, 0)  # baseline interval (in s)
cnorm = TwoSlopeNorm(vmin=vmin, vcenter=0, vmax=vmax)  # min, center & max ERDS

kwargs = dict(
    n_permutations=100, step_down_p=0.05, seed=1, buffer_size=None, out_type="mask"
)  # for cluster test

tfr = tfr_multitaper(
    epochs,
    freqs=freqs,
    n_cycles=freqs,
    use_fft=True,
    return_itc=False,
    average=False,
    decim=2,
)
tfr.crop(-1.5, 4).apply_baseline(baseline, mode="percent")

for event in event_ids:
    # select desired epochs for visualization
    tfr_ev = tfr[event]
    fig, axes = plt.subplots(
        1, 4, figsize=(12, 4), gridspec_kw={"width_ratios": [10, 10, 10, 1]}
    )
    for ch, ax in enumerate(axes[:-1]):  # for each channel
        # positive clusters
        _, c1, p1, _ = pcluster_test(tfr_ev.data[:, ch], tail=1, **kwargs)
        # negative clusters
        _, c2, p2, _ = pcluster_test(tfr_ev.data[:, ch], tail=-1, **kwargs)

        # note that we keep clusters with p <= 0.05 from the combined clusters
        # of two independent tests; in this example, we do not correct for
        # these two comparisons
        c = np.stack(c1 + c2, axis=2)  # combined clusters
        p = np.concatenate((p1, p2))  # combined p-values
        mask = c[..., p <= 0.05].any(axis=-1)

        # plot TFR (ERDS map with masking)
        tfr_ev.average().plot(
            [ch],
            cmap="RdBu",
            cnorm=cnorm,
            axes=ax,
            colorbar=False,
            show=False,
            mask=mask,
            mask_style="mask",
        )

        ax.set_title(epochs.ch_names[ch], fontsize=10)
        ax.axvline(0, linewidth=1, color="black", linestyle=":")  # event
        if ch != 0:
            ax.set_ylabel("")
            ax.set_yticklabels("")
    fig.colorbar(axes[0].images[-1], cax=axes[-1]).ax.set_yscale("linear")
    fig.suptitle(f"ERDS ({event})")
    plt.show()
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.8s remaining:    0.0s
# Not setting metadata
# Applying baseline correction (mode: percent)
# Using a threshold of 1.664371
# stat_fun(H1): min=-4.874461 max=4.694100
# Running initial clustering …
# Found 26 clusters
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    1.3s finished
# 100%|██████████| Permuting : 99/99 [00:01<00:00,   95.32it/s]
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  111.36it/s]
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  115.72it/s]
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Using a threshold of -1.664371
# stat_fun(H1): min=-4.874461 max=4.694100
# Running initial clustering …
# Found 15 clusters
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  121.53it/s]
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# No baseline correction applied
# Using a threshold of 1.664371
# stat_fun(H1): min=-3.690385 max=6.539322
# Running initial clustering …
# Found 47 clusters
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  119.65it/s]
# Step-down-in-jumps iteration #1 found 3 clusters to exclude from subsequent iterations
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  120.53it/s]
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Using a threshold of -1.664371
# stat_fun(H1): min=-3.690385 max=6.539322
# Running initial clustering …
# Found 23 clusters
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  117.16it/s]
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# No baseline correction applied
# Using a threshold of 1.664371
# stat_fun(H1): min=-7.491352 max=4.425566
# Running initial clustering …
# Found 30 clusters
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  120.97it/s]
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  123.31it/s]
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Using a threshold of -1.664371
# stat_fun(H1): min=-7.491352 max=4.425566
# Running initial clustering …
# Found 24 clusters
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  119.76it/s]
# Step-down-in-jumps iteration #1 found 1 cluster to exclude from subsequent iterations
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  121.31it/s]
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# No baseline correction applied
# Using a threshold of 1.664371
# stat_fun(H1): min=-3.897779 max=4.123073
# Running initial clustering …
# Found 40 clusters
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  120.36it/s]
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  122.70it/s]
# Step-down-in-jumps iteration #2 found 1 additional cluster to exclude from subsequent iterations
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  120.53it/s]
# Step-down-in-jumps iteration #3 found 0 additional clusters to exclude from subsequent iterations
# Using a threshold of -1.664371
# stat_fun(H1): min=-3.897779 max=4.123073
# Running initial clustering …
# Found 24 clusters
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  121.24it/s]
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# No baseline correction applied
# Using a threshold of 1.664371
# stat_fun(H1): min=-2.859567 max=3.805873
# Running initial clustering …
# Found 53 clusters
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  122.06it/s]
# Step-down-in-jumps iteration #1 found 3 clusters to exclude from subsequent iterations
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  120.24it/s]
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Using a threshold of -1.664371
# stat_fun(H1): min=-2.859567 max=3.805873
# Running initial clustering …
# Found 23 clusters
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  119.09it/s]
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# No baseline correction applied
# Using a threshold of 1.664371
# stat_fun(H1): min=-6.198971 max=5.149242
# Running initial clustering …
# Found 54 clusters
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  122.87it/s]
# Step-down-in-jumps iteration #1 found 2 clusters to exclude from subsequent iterations
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  111.28it/s]
# Step-down-in-jumps iteration #2 found 0 additional clusters to exclude from subsequent iterations
# Using a threshold of -1.664371
# stat_fun(H1): min=-6.198971 max=5.149242
# Running initial clustering …
# Found 29 clusters
# 100%|██████████| Permuting : 99/99 [00:00<00:00,  112.76it/s]
# Step-down-in-jumps iteration #1 found 0 clusters to exclude from subsequent iterations
# No baseline correction applied

# %% [markdown]
# # CSP

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import ShuffleSplit,StratifiedKFold ,cross_val_score, cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder

from mne import Epochs, pick_types, events_from_annotations, create_info
from mne.channels import make_standard_montage
from mne.io import concatenate_raws, read_raw_edf
from mne.datasets import eegbci
from mne.decoding import CSP
from mne.time_frequency import AverageTFR

# %%
eeg1 = raw.copy().filter(l_freq=1.0, h_freq=30.0, method = 'iir', iir_params= {"order": 12, "ftype":'butter'})
# eeg1 = eeg1.copy().set_eeg_reference(ref_channels="average")

eeg1= eeg1.pick_channels(['C3','Cz','C4'])
events, _ = mne.events_from_annotations(eeg1)
event_ids = dict(Right=7, Tongue=9)

epochs = mne.Epochs(eeg1, events, 
        tmin=-2.0,     # init timestamp of epoch (0 means trigger timestamp same as event start)
        tmax=4.0,    # final timestamp (10 means set epoch duration 10 second)
        event_id= event_ids,
        preload = True,
        event_repeated='drop'
    )

CSP_train = epochs.copy().crop(tmin=0.0, tmax=3.5)
labels = epochs.events[:, -1]
# Out:
# Filtering raw data in 5 contiguous segments
# Setting up band-pass filter from 1 - 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth bandpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 48 (effective, after forward-backward)
# - Cutoffs at 1.00, 30.00 Hz: -6.02, -6.02 dB
# Used Annotations descriptions: ['OVTK_GDF_Correct', 'OVTK_GDF_Cross_On_Screen', 'OVTK_GDF_End_Of_Session', 'OVTK_GDF_End_Of_Trial', 'OVTK_GDF_Feedback_Continuous', 'OVTK_GDF_Incorrect', 'OVTK_GDF_Right', 'OVTK_GDF_Start_Of_Trial', 'OVTK_GDF_Tongue', 'OVTK_StimulationId_BaselineStart', 'OVTK_StimulationId_BaselineStop', 'OVTK_StimulationId_Beep', 'OVTK_StimulationId_ExperimentStart', 'OVTK_StimulationId_ExperimentStop', 'OVTK_StimulationId_Train']
# Not setting metadata
# 160 matching events found
# Setting baseline interval to [-2.0, 0.0] sec
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 160 events and 751 original time points ...
# 0 bad epochs dropped

# %%
# Define a monte-carlo cross-validation generator (reduce variance):
scores = []
CSP_epochs_data = epochs.get_data()
CSP_epochs_data_train = CSP_train.get_data()
cv = ShuffleSplit(5, test_size=0.2, random_state=42)
cv_split = cv.split(CSP_epochs_data_train)

# Assemble a classifier
lda = LinearDiscriminantAnalysis()
csp = CSP(n_components=3, reg=None, log=True, norm_trace=False)

# Use scikit-learn Pipeline with cross_val_score function
clf = Pipeline([("CSP", csp), ("LDA", lda)])
scores = cross_val_score(clf, CSP_epochs_data_train, labels, cv=cv, n_jobs=None)
CSP_predicted = cross_val_predict(clf, CSP_epochs_data_train, labels, cv=5)
# Printing the results
class_balance = np.mean(labels == labels[0])
class_balance = max(class_balance, 1.0 - class_balance)

# plot CSP patterns estimated on full data for visualization
CSP_coff = csp.fit_transform(CSP_epochs_data, labels)

csp.plot_patterns(epochs.info, ch_type="eeg", units="Patterns (AU)", size=1.5)

print(
    "Classification accuracy: %f / Chance level: %f" % (np.mean(scores), class_balance)
)

conf_matrix = confusion_matrix(labels, CSP_predicted)
print(conf_matrix)
# Out:
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2 (2.2e-16 eps * 3 dim * 1.8e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 2e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2 (2.2e-16 eps * 3 dim * 1.8e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2 (2.2e-16 eps * 3 dim * 1.8e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.9 (2.2e-16 eps * 3 dim * 2.8e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.9 (2.2e-16 eps * 3 dim * 2.8e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# <MNEFigure size 900x287.5 with 4 Axes>
# Classification accuracy: 0.675000 / Chance level: 0.500000
# [[59 21]
#  [25 55]]

# %%
shape = np.shape(CSP_train.get_data())
array_2d = CSP_train.get_data().reshape(shape[0], shape[1]*shape[2])

scores = cross_val_score(lda, array_2d, labels, cv=cv, n_jobs=None)
CSP_predicted = cross_val_predict(lda, array_2d, labels, cv=5)

conf_matrix = confusion_matrix(labels, CSP_predicted)
print("LDA only classification scores", np.mean(scores))
print(conf_matrix)
# Out:
# LDA only classification scores 0.75625
# [[56 24]
#  [26 54]]

# %%
sfreq = eeg1.info["sfreq"]
w_length = int(sfreq * 0.5)  # running classifier: window length
w_step = int(sfreq * 0.1)  # running classifier: window step size
w_start = np.arange(0, CSP_epochs_data.shape[2] - w_length, w_step)

scores_windows = []

for train_idx, test_idx in cv_split:
    y_train, y_test = labels[train_idx], labels[test_idx]

    X_train = csp.fit_transform(CSP_epochs_data_train[train_idx], y_train)
    X_test = csp.transform(CSP_epochs_data_train[test_idx])

    # fit classifier
    lda.fit(X_train, y_train)

    # running classifier: test classifier on sliding window
    score_this_window = []
    for n in w_start:
        X_test = csp.transform(CSP_epochs_data[test_idx][:, :, n : (n + w_length)])
        score_this_window.append(lda.score(X_test, y_test))
    scores_windows.append(score_this_window)

# Plot scores over time
w_times = (w_start + w_length / 2.0) / sfreq + epochs.tmin

plt.figure()
plt.plot(w_times, np.mean(scores_windows, 0), label="Score")
plt.axvline(0, linestyle="--", color="k", label="Onset")
plt.axhline(0.5, linestyle="-", color="k", label="Chance")
plt.xlabel("time (s)")
plt.ylabel("classification accuracy")
plt.title("Classification score over time")
plt.legend(loc="lower right")
plt.show()
# Out:
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2 (2.2e-16 eps * 3 dim * 1.8e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 2e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2 (2.2e-16 eps * 3 dim * 1.8e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2 (2.2e-16 eps * 3 dim * 1.9e+15  max singular value)
#     Estimated rank (mag): 3
#     MAG: rank 3 computed from 3 data channels with 0 projectors
# Reducing data rank from 3 -> 3
# Estimating covariance using EMPIRICAL
# Done.

# %%
# Classification & time-frequency parameters
tmin, tmax = 0.000, 3.500
n_cycles = 10.0  # how many complete cycles: used to define window size
min_freq = 1.0
max_freq = 30.0
n_freqs = 8 # how many frequency bins to use

# Assemble list of frequency range tuples
freqs = np.linspace(min_freq, max_freq, n_freqs)  # assemble frequencies
freq_ranges = list(zip(freqs[:-1], freqs[1:]))  # make freqs list of tuples

# Infer window spacing from the max freq and number of cycles to avoid gaps
window_spacing = n_cycles / np.max(freqs) / 2.0
centered_w_times = np.arange(tmin, tmax, window_spacing)[1:]
n_windows = len(centered_w_times)

# Instantiate label encoder
le = LabelEncoder()

freq_scores = np.zeros((n_freqs - 1,))

# Loop through each frequency range of interest
for freq, (fmin, fmax) in enumerate(freq_ranges):
    # Infer window size based on the frequency being used
    w_size = n_cycles / ((fmax + fmin) / 2.0)  # in seconds

    # Apply band-pass filter to isolate the specified frequencies
    CSP_filter = raw.copy().filter(
        fmin, fmax, fir_design="firwin", skip_by_annotation="edge"
    )

    # Extract epochs from filtered data, padded by window size
    CSP_epochs2 = Epochs(
        CSP_filter,
        events,
        event_ids,
        tmin - w_size,
        tmax + w_size,
        picks=("Fz","C3", "Cz", "C4","Pz"),
        proj=False,
        baseline=None,
        preload=True,
    )
    # CSP_epochs2.drop_bad()
    y = le.fit_transform(CSP_epochs2.events[:, 2])

    X = CSP_epochs2.get_data()

    # Save mean scores over folds for each frequency and time window
    freq_scores[freq] = np.mean(
        cross_val_score(estimator=clf, X=X, y=y, cv=cv), axis=0
    )

plt.bar(
    freqs[:-1], freq_scores, width=np.diff(freqs)[0], align="edge", edgecolor="black"
)
plt.xticks(freqs)
plt.ylim([0, 1])
plt.legend()
plt.xlabel("Frequency (Hz)")
plt.ylabel("Decoding Scores")
plt.title("Frequency Decoding Scores")
plt.show()
# Out:
# Filtering raw data in 5 contiguous segments
# Setting up band-pass filter from 1 - 5.1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 5.14 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 6.14 Hz)
# - Filter length: 413 samples (3.304 sec)
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Using data from preloaded Raw for 160 events and 1252 original time points ...
# 0 bad epochs dropped
# Computing rank from data with rank=None
#     Using tolerance 5.2 (2.2e-16 eps * 5 dim * 4.7e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.5 (2.2e-16 eps * 5 dim * 5e+15  max singular value)
#     Estimated rank (mag): 5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.0s finished
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.1 (2.2e-16 eps * 5 dim * 4.6e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.7 (2.2e-16 eps * 5 dim * 6.1e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.1 (2.2e-16 eps * 5 dim * 4.6e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.1 (2.2e-16 eps * 5 dim * 4.6e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.3 (2.2e-16 eps * 5 dim * 4.8e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.8 (2.2e-16 eps * 5 dim * 6.1e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.1 (2.2e-16 eps * 5 dim * 4.6e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.2 (2.2e-16 eps * 5 dim * 4.6e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Filtering raw data in 5 contiguous segments
# Setting up band-pass filter from 5.1 - 9.3 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 5.14
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 4.14 Hz)
# - Upper passband edge: 9.29 Hz
# - Upper transition bandwidth: 2.32 Hz (-6 dB cutoff frequency: 10.45 Hz)
# - Filter length: 207 samples (1.656 sec)
#
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Using data from preloaded Raw for 160 events and 785 original time points ...
# 0 bad epochs dropped
# Computing rank from data with rank=None
#     Using tolerance 1.9 (2.2e-16 eps * 5 dim * 1.7e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8 (2.2e-16 eps * 5 dim * 1.7e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.0s finished
#     Using tolerance 1.9 (2.2e-16 eps * 5 dim * 1.7e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.9 (2.2e-16 eps * 5 dim * 1.7e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2 (2.2e-16 eps * 5 dim * 1.8e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8 (2.2e-16 eps * 5 dim * 1.6e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.9 (2.2e-16 eps * 5 dim * 1.7e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.9 (2.2e-16 eps * 5 dim * 1.7e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.9 (2.2e-16 eps * 5 dim * 1.7e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.9 (2.2e-16 eps * 5 dim * 1.7e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Filtering raw data in 5 contiguous segments
# Setting up band-pass filter from 9.3 - 13 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 9.29
# - Lower transition bandwidth: 2.32 Hz (-6 dB cutoff frequency: 8.12 Hz)
# - Upper passband edge: 13.43 Hz
# - Upper transition bandwidth: 3.36 Hz (-6 dB cutoff frequency: 15.11 Hz)
# - Filter length: 179 samples (1.432 sec)
#
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Using data from preloaded Raw for 160 events and 659 original time points ...
# 0 bad epochs dropped
# Computing rank from data with rank=None
#     Using tolerance 1.5 (2.2e-16 eps * 5 dim * 1.4e+15  max singular value)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.0s finished
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4 (2.2e-16 eps * 5 dim * 1.3e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.5 (2.2e-16 eps * 5 dim * 1.3e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4 (2.2e-16 eps * 5 dim * 1.3e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.5 (2.2e-16 eps * 5 dim * 1.4e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4 (2.2e-16 eps * 5 dim * 1.2e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.5 (2.2e-16 eps * 5 dim * 1.4e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4 (2.2e-16 eps * 5 dim * 1.3e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.5 (2.2e-16 eps * 5 dim * 1.3e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4 (2.2e-16 eps * 5 dim * 1.3e+15  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Filtering raw data in 5 contiguous segments
# Setting up band-pass filter from 13 - 18 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 13.43
# - Lower transition bandwidth: 3.36 Hz (-6 dB cutoff frequency: 11.75 Hz)
# - Upper passband edge: 17.57 Hz
# - Upper transition bandwidth: 4.39 Hz (-6 dB cutoff frequency: 19.77 Hz)
# - Filter length: 123 samples (0.984 sec)
#
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Using data from preloaded Raw for 160 events and 600 original time points ...
# 0 bad epochs dropped
# Computing rank from data with rank=None
#     Using tolerance 1 (2.2e-16 eps * 5 dim * 9.3e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.0s finished
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1 (2.2e-16 eps * 5 dim * 9.2e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1 (2.2e-16 eps * 5 dim * 9.1e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1 (2.2e-16 eps * 5 dim * 9.4e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1 (2.2e-16 eps * 5 dim * 9.5e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.98 (2.2e-16 eps * 5 dim * 8.8e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1 (2.2e-16 eps * 5 dim * 9.2e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1 (2.2e-16 eps * 5 dim * 9.3e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1 (2.2e-16 eps * 5 dim * 9.2e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1 (2.2e-16 eps * 5 dim * 9.2e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Filtering raw data in 5 contiguous segments
# Setting up band-pass filter from 18 - 22 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 17.57
# - Lower transition bandwidth: 4.39 Hz (-6 dB cutoff frequency: 15.38 Hz)
# - Upper passband edge: 21.71 Hz
# - Upper transition bandwidth: 5.43 Hz (-6 dB cutoff frequency: 24.43 Hz)
# - Filter length: 95 samples (0.760 sec)
#
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Using data from preloaded Raw for 160 events and 566 original time points ...
# 0 bad epochs dropped
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.0s finished
# Computing rank from data with rank=None
#     Using tolerance 0.78 (2.2e-16 eps * 5 dim * 7e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.76 (2.2e-16 eps * 5 dim * 6.9e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.77 (2.2e-16 eps * 5 dim * 6.9e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.77 (2.2e-16 eps * 5 dim * 6.9e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.8 (2.2e-16 eps * 5 dim * 7.2e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.74 (2.2e-16 eps * 5 dim * 6.6e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.77 (2.2e-16 eps * 5 dim * 7e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.77 (2.2e-16 eps * 5 dim * 7e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.78 (2.2e-16 eps * 5 dim * 7e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.77 (2.2e-16 eps * 5 dim * 6.9e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Filtering raw data in 5 contiguous segments
# Setting up band-pass filter from 22 - 26 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 21.71
# - Lower transition bandwidth: 5.43 Hz (-6 dB cutoff frequency: 19.00 Hz)
# - Upper passband edge: 25.86 Hz
# - Upper transition bandwidth: 6.46 Hz (-6 dB cutoff frequency: 29.09 Hz)
# - Filter length: 77 samples (0.616 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.0s finished
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Using data from preloaded Raw for 160 events and 544 original time points ...
# 0 bad epochs dropped
# Computing rank from data with rank=None
#     Using tolerance 0.63 (2.2e-16 eps * 5 dim * 5.6e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.62 (2.2e-16 eps * 5 dim * 5.6e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.61 (2.2e-16 eps * 5 dim * 5.5e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.62 (2.2e-16 eps * 5 dim * 5.6e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.64 (2.2e-16 eps * 5 dim * 5.7e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.6 (2.2e-16 eps * 5 dim * 5.4e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.61 (2.2e-16 eps * 5 dim * 5.5e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.63 (2.2e-16 eps * 5 dim * 5.7e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.62 (2.2e-16 eps * 5 dim * 5.6e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.63 (2.2e-16 eps * 5 dim * 5.6e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Filtering raw data in 5 contiguous segments
# Setting up band-pass filter from 26 - 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.86
# - Lower transition bandwidth: 6.46 Hz (-6 dB cutoff frequency: 22.63 Hz)
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 65 samples (0.520 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.0s finished
# Not setting metadata
# 160 matching events found
# No baseline correction applied
# Using data from preloaded Raw for 160 events and 528 original time points ...
# 0 bad epochs dropped
# Computing rank from data with rank=None
#     Using tolerance 0.5 (2.2e-16 eps * 5 dim * 4.5e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.51 (2.2e-16 eps * 5 dim * 4.6e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.49 (2.2e-16 eps * 5 dim * 4.4e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.52 (2.2e-16 eps * 5 dim * 4.6e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.51 (2.2e-16 eps * 5 dim * 4.6e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.49 (2.2e-16 eps * 5 dim * 4.4e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.49 (2.2e-16 eps * 5 dim * 4.4e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.51 (2.2e-16 eps * 5 dim * 4.6e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.49 (2.2e-16 eps * 5 dim * 4.4e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 0.51 (2.2e-16 eps * 5 dim * 4.6e+14  max singular value)
#     Estimated rank (mag): 5
#     MAG: rank 5 computed from 5 data channels with 0 projectors
# Reducing data rank from 5 -> 5
# Estimating covariance using EMPIRICAL
# Done.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
